# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Import-Libraries" data-toc-modified-id="Import-Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Import Libraries</a></span></li><li><span><a href="#Set-Arguments" data-toc-modified-id="Set-Arguments-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Set Arguments</a></span></li><li><span><a href="#Test-Individual-Functionalities" data-toc-modified-id="Test-Individual-Functionalities-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Test Individual Functionalities</a></span></li><li><span><a href="#Test-All-Functionalities" data-toc-modified-id="Test-All-Functionalities-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Test All Functionalities</a></span></li></ul></div>

# %% [markdown]
# # Import Libraries

# %%
from time import sleep
from random import randrange
from sys import maxsize
import pandas as pd
from appwrite.client import Client
from appwrite.services.users import Users
from appwrite.services.databases import Databases
from appwrite.services.storage import Storage
from appwrite.services.account import Account
from appwrite.services.functions import Functions
from appwrite.input_file import InputFile
from appwrite.permission import Permission
from appwrite.role import Role
from appwrite.id import ID

# Helper method to print green colored output.
def p(info):
    print("\033[32;1m"+str(info)+"\033[0m")

# %% [markdown]
# # Set Arguments

# %%
# Read the docs at https://appwrite.io/docs to get more information
# about API keys and Project IDs
client = Client()
client.endpoint = 'http://MY_HOSTNAME/v1'
client.project = 'my_project_id'
client.key = 'MY_SECRET_KEY'
client.self_signed=False
# client.set_jwt('JWT') # Use this to authenticate with JWT instead of API_KEY

databases = Databases(client)
storage = Storage(client)
functions = Functions(client)
users = Users(client)

database_id = 'database_id'
collection_id = 'collection_id'
document_id = 'document_id'
user_id = 'user_id'
bucket_id = 'bucket_id'
file_id = 'file_id'
# document_id = None

# %% [markdown]
# # Test Individual Functionalities

# %%
def create_database():
    global database_id

    p("Running Create Database API")
    response = databases.create(
        database_id=ID.unique(),
        name='Movies',
    )
    database_id = response['$id']
    print(response)
    
create_database()
# Out:
# Running Create Database API
# {'$id': '63ff5933737f37fc287b', 'name': 'Movies', '$createdAt': '2023-03-01T13:54:59.473+00:00', '$updatedAt': '2023-03-01T13:54:59.473+00:00'}

# %%
def create_collection():
    global collection_id

    p("Running Create Collection API")
    response = databases.create_collection(
        database_id,
        collection_id=ID.unique(),
        name='Movies',
        document_security=True,
        permissions=[
            Permission.read(Role.any()),
            Permission.create(Role.users()),
            Permission.update(Role.users()),
            Permission.delete(Role.users()),
        ]
    )

    collection_id = response['$id']
    print(response)

    response = databases.create_string_attribute(
        database_id,
        collection_id,
        key='name',
        size=255,
        required=True,
    )
    print(response)

    response = databases.create_integer_attribute(
        database_id,
        collection_id,
        key='release_year',
        required=True,
        min=0,
        max=9999
    )
    print(response)

    response = databases.create_float_attribute(
        database_id,
        collection_id,
        key='rating',
        required=True,
        min=0.0,
        max=99.99
    )
    print(response)

    response = databases.create_boolean_attribute(
        database_id,
        collection_id,
        key='kids',
        required=True
    )
    print(response)

    response = databases.create_email_attribute(
        database_id,
        collection_id,
        key='email',
        required=False,
        default=""
    )
    print(response)

    # Wait for attributes to be created
    sleep(2)

    response = databases.create_index(
        database_id,
        collection_id,
        key='name_email_idx',
        type="fulltext",
        attributes=['name', 'email']
    )
    print(response)
    
create_collection()
# Out:
# Running Create Collection API
# {'$id': '63ff594cd836f0e980b6', '$createdAt': '2023-03-01T13:55:24.886+00:00', '$updatedAt': '2023-03-01T13:55:24.886+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'databaseId': '63ff5933737f37fc287b', 'name': 'Movies', 'enabled': True, 'documentSecurity': True, 'attributes': [], 'indexes': []}
# {'key': 'name', 'type': 'string', 'status': 'processing', 'required': True, 'array': False, 'size': 255, 'default': None}
# {'key': 'release_year', 'type': 'integer', 'status': 'processing', 'required': True, 'array': False, 'min': 0, 'max': 9999, 'default': None}
# {'key': 'rating', 'type': 'double', 'status': 'processing', 'required': True, 'array': False, 'min': 0, 'max': 99.99, 'default': None}
# {'key': 'kids', 'type': 'boolean', 'status': 'processing', 'required': True, 'array': False, 'default': None}
# {'key': 'email', 'type': 'string', 'status': 'processing', 'required': False, 'array': False, 'format': 'email', 'default': None}
# {'key': 'name_email_idx', 'type': 'fulltext', 'status': 'processing', 'attributes': ['name', 'email'], 'orders': []}

# %%
def list_collections():
    p("Running List Collection API")
    response = databases.list_collections(database_id)
    print(response)
    
list_collections()
# Out:
# Running List Collection API
# {'total': 1, 'collections': [{'$id': '63ff594cd836f0e980b6', '$createdAt': '2023-03-01T13:55:24.886+00:00', '$updatedAt': '2023-03-01T13:55:24.886+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'databaseId': '63ff5933737f37fc287b', 'name': 'Movies', 'enabled': True, 'documentSecurity': True, 'attributes': [{'key': 'name', 'type': 'string', 'status': 'available', 'required': True, 'array': False, 'size': 255, 'default': None}, {'key': 'release_year', 'type': 'integer', 'status': 'available', 'required': True, 'array': False, 'min': 0, 'max': 9999, 'default': None}, {'key': 'rating', 'type': 'double', 'status': 'available', 'required': True, 'array': False, 'min': 0, 'max': 99.99, 'default': None}, {'key': 'kids', 'type': 'boolean', 'status': 'available', 'required': True, 'array': False, 'default': None}, {'key': 'email', 'type': 'string', 'status': 'available', 'required': False, 'array': False, 'format': 'email', 'default': None}], 'indexes': [{'key': 'name_email_idx', 'type': 'fulltext', 'status': 'available', 'attributes': ['name', 'email'], 'orders': []}]}]}

# %%
def get_account():
    account = Account(client)
    p("Running Get Account API");
    response = account.get()
    print(response)
    
get_account()
# Out:
# Running Get Account API
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/appwrite/client.py:130, in Client.call(self, method, path, headers, params)
#     119 response = requests.request(  # call method dynamically https://stackoverflow.com/a/4246075/2299554
#     120     method=method,
#     121     url=self._endpoint + path,
#    (...)
#     127     verify=(not self._self_signed),
#     128 )
# --> 130 response.raise_for_status()
#     132 content_type = response.headers['Content-Type']
#
# File /usr/lib/python3/dist-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: http://127.0.0.1:899/v1/account
#
# During handling of the above exception, another exception occurred:
#
# AppwriteException                         Traceback (most recent call last)
# Cell In [6], line 7
#       4     response = account.get()
#       5     print(response)
# ----> 7 get_account()
#
# Cell In [6], line 4, in get_account()
#       2 account = Account(client)
#       3 p("Running Get Account API");
# ----> 4 response = account.get()
#       5 print(response)
#
# File ~/.local/lib/python3.11/site-packages/appwrite/services/account.py:16, in Account.get(self)
#      13 path = '/account'
#      14 params = {}
# ---> 16 return self.client.call('get', path, {
#      17     'content-type': 'application/json',
#      18 }, params)
#
# File ~/.local/lib/python3.11/site-packages/appwrite/client.py:142, in Client.call(self, method, path, headers, params)
#     140 content_type = response.headers['Content-Type']
#     141 if content_type.startswith('application/json'):
# --> 142     raise AppwriteException(response.json()['message'], response.status_code, response.json().get('type'), response.json())
#     143 else:
#     144     raise AppwriteException(response.text, response.status_code)
#
# AppwriteException: app.63c39409d6a8a5cd05bd@service.127.0.0.1 (role: applications) missing scope (account)

# %%
def add_doc():
    global document_id

    p("Running Add Document API")
    response = databases.create_document(
        database_id,
        collection_id,
        document_id=ID.unique(),
        data={
            'name': "Spider Man",
            'release_year': 1920,
            'rating': 98.5,
            'kids': False
        },
        permissions=[
            Permission.read(Role.users()),
            Permission.update(Role.users()),
            Permission.delete(Role.users()),
        ]
    )
    document_id = response['$id']
    print(response)
    
add_doc()
# Out:
# Running Add Document API
# {'name': 'Spider Man', 'release_year': 1920, 'rating': 98.5, 'kids': False, '$id': '63ff59a6cd9f3343eebe', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$createdAt': '2023-03-01T13:56:54.842+00:00', '$updatedAt': '2023-03-01T13:56:54.842+00:00', 'email': None, '$collectionId': '63ff594cd836f0e980b6', '$databaseId': '63ff5933737f37fc287b'}

# %%
for indx,data in   channelsdf.iterrows():
# #     print(indx)
#     print(data['channel_name'])
#     print(data['channel_url'])
#     print(data)
    messagesdf.fillna('',inplace=True)
    time_list = messagesdf.loc[messagesdf['channel_url'] == data['channel_url']]['time'].tolist()
#     dt_time_list = [datetime.datetime.strptime(time_str, '%Y-%m-%d %H:%M:%S') for time_str in time_list]
    response = databases.create_document(
        '64003d8507c5fd8322bf',
        '64003ebf13d3e4e89ed9',
        document_id=ID.unique(),
        data={
            'channel_url': data['channel_url'],
            'message_list': messagesdf.loc[messagesdf['channel_url'] == data['channel_url']]['message'].tolist(),
            'message_time_list':time_list
        },
        permissions=[
            Permission.read(Role.users()),
            Permission.update(Role.users()),
            Permission.delete(Role.users()),
        ]
    )
    document_id = response['$id']
    print(response)
# Out:
# {'channel_url': 'https://t.me/stockpro_online', 'message_list': ['❇️ADANI PORTS MADE A HIGH OF 622.5', 'Expiry range\n\nNIFTY - 17280-340\nBANKNIFTY  - 40250-400', 'VOLTAS made a high of 925🚀🚀🚀', 'NIFTY\n17300 - Support. Both Long and Short build up.\nLongs - 1.64CR (Intraday -83.27L)\nShorts - 37.01L (Intraday - 22.71L)\n17350 - Support. Long build up.\nLongs - 1.16CR (Intraday - 64.02L)\nShorts - 54.32L (Intraday - 46.22L)\n17400 - Strong  Resistance. Both long and short build up.\nLongs - 1.25CR (Intraday - 14.62L)\nShorts - 2.12CR (Intraday - 1.51CR)\n\n\nBANKNIFTY\n39000 - Support. No considerable OI change.\nLongs - 36.82L (Intraday - 10.03L)\nShorts - 1.29L (Intraday - minus 9900)\n39500 - Support. Long build up.\nLongs - 38.27L (Intraday - 16.05L)\nShorts - 1.06L (Intraday - minus 18750)\n40000 - Support. Long unwinding.\nLongs - 46.52L (Intraday - 9.65L)\nShorts - 6.79L (Intraday - minus 1.60L)\n40500 - Support. Both Long and Short build up.\nLongs - 92.79L (Intraday - 55.56L)\nShorts - 40.06L (Intraday - 19.33L)\n40600 - Congestion zone. \nLongs - 62.39L (Intraday - 38.67L)\nShorts - 69.19L (Intraday - 57.15L)\n40700 - Resistance., Long unwinding and Short build up.\nLongs - 34.06L (Intraday - 16.30L)\nShorts - 1.01CR (Intraday - 78.87L)\n41000 - Resistance. Short covering.\nLongs - 7.28L (Intraday - 1.45L)\nShorts - 61.97L (Intraday - 28.92L)\n\nData still neutral with negative bias.\nVIX 0.17% down, flat.\nDOW FUTs 20pts positive, losing gains, negative.\nStill range bound indication volatile move after 1.30PM', '🔰 WE ANNOUNCE MASTER TRADER COURSE MARCH 2023 BATCH😎😎\n\n🔰ENROLL NOW AND GET EARLY ENROLLMENT BENEFITS\n\n✅ COMPLIMENATRY IMMEDIATE ACCESS TO ALL 5 PREMIUM AND ROCKSTAR GROUPS, THE DAY YOU ENROLL FOR THE COURSE\n✅COMPLIMENATRY ACCESS TO STOCKPRO LIBRARY WHERE YOU CAN READ QUALITY BOOKS\n✅COMPLIMENATRY ACCESS TO RISK MANAGEMENT, MONEY MANAGEMENT AND TRADE MANAGEMENT CLASSES\n✅COMPLIMENATRY ACCESS TO ALL IN ONE TRADING COURSE ON WEBSITE\n✅COMPLIMENATRY ACCESS TO IMPORTANT PREREQUISITES\n✅ COMPLIMENTARY ACCESS TO COMMODITY-MCX COURSE\n\n👉CONTACT STOCKPRO-TEAM NOW\n\n📞Mobile Numbers: +91 9897130608\n\n📱Whatsapp: https://wa.me/919897130608', '', '❇️HCLTECH - MADE A HIGH OF 1115 SO FAR', 'POWER OF STOCKPRO RESEARCH\n\n❇️EXCELINDUS - MADE A HIGH OF 949\n\n❇️OUR ENTRY WAS 935\n\n❇️STOCK DELIVERED POTENTIAL 14 POINTS', 'VENKEYS - MADE A HIGH OF 1662', 'POWER OF STOCKPRO RESEARCH\n\n❇️HEROMOTOCO - MADE A HIGH OF 2480\n\n❇️OUR ENTRY WAS 2460\n\n❇️STOCK DELIVERED POTENTIAL 20POINTS', 'POWER OF STOCKPRO RESEARCH\n\n❇️VOLTAS - MADE A HIGH OF 924.90\n\n❇️OUR ENTRY WAS 911\n\n❇️STOCK DELIVERED POTENTIAL 13 POINTS', '❇️GUJGASLTD - MADE A HIGH OF 518', 'HCLTECH MADE A HIGH OF 1115.7🚀🚀🚀', '', '📊POWER OF STOCKPRO RESEARCH😍😍\n\n✅VOLTAS - WE TOLD YOU IN MORNING THAT IT IS LOOKING GOOD ABOVE 911\n\n✅IT MADE A HIGH OF 922 SO FAR\n\n✅11 POINTS DONE🎯🎯🎯💪💪💪😎😎😎', 'HERO MOTO at 2475', 'VOLTAS about to touch 917🚀🚀🚀', 'HCLTECH Looks Good ABOVE 1110', 'NIFTY\n17300 -  Strong Support\nLongs - 1.50CR (Intraday - 69.49L)\nShorts - 36.47L (Intraday - 22.17L)\n17350 - Support.\nLongs - 98.84L (Intraday - 47.43L)\nShorts - 54.51L (Intraday - 46.42L)\n17400 - Strong Resistance\nLongs - 1.15CR (Intraday - 4.47L)\nShorts - 2.02CR (Intraday - 1.41CR)\n\nBANKNIFTY\n39000 - Support.\nLongs - 37.95L (Intraday - 1.11L)\nShorts - 1.33L (Intraday - minus 5900)\n39500 - Support.\nLongs - 36.84L (Intraday - 14.62L)\nShorts - 1.09L (Intraday - minus 15050)\n40000 - Support.\nLongs - 50.25L (Intraday - 13.38L)\nShorts - 6.64L (Intraday - minus 1.75L)\n40500 - Support.\nLongs - 78.86L (Intraday - 41.63L)\nShorts - 32.60L (Intraday - 11.87L)\n40700 - Resistance\nLongs - 40.13L (Intraday - 22.38L)\nShorts 84.51L (intraday - 61.78L)\n41000 - Resistance\nLongs - 9.00L (Intraday - 3.17L)\nShorts - 70.10L (Intraday - 37.04L)\n\nData neutral for both indices.\nVIX 1.39% up, negative\nDOW FUTs 33pts up, positive.\nMarkets looks range bound for first half.', 'TWL Look ...
# {'channel_url': 'https://t.me/ushasanalysis', 'message_list': ['BTST CANDIDATE\n\nBDL AT 952', 'SHORT TERM FUTURES\n\nSELL VOLTAS MARCH FUTURES AT 910\n\nTARGET OPEN\n\nSTOP LOSS 930', 'DLF MARCH FUTURES\n\n360', 'SHORT TERM FUTURES\n\nBUY DLF MARCH FUTURES AT 358\n\nTARGET OPEN\n\nSTOP LOSS AT 348', 'SHORT TERM EQUITY\n\nBUY EIDPARRY AT 517\n\nTARGET 530,550,570+\n\nSTOP LOSS 495', '1620\n\nBOOK PROFITS  OR KEEP TRAILING!', 'ADANIENT 1582👍👍', "MEMBER'S LOOKING TO JOIN OUR HIGH PROFIT SERVICES CAN MAKE PAYMENT HERE\n\nSPECIAL OFFERS AVAILABLE", 'https://rpy.club/g/m5r6uqynwN', "MEMBER'S LOOKING TO JOIN OUR SHORT TERM EQUITY SERVICES CAN MAKE PAYMENT HERE\n\nUSE COUPON CODE\n\nSPECIAL20\n\nGET FLAT 20% OFF ON YEARLY AND LIFETIME MEMBERSHIP 👍👍", 'https://rpy.club/g/75WAelBONI', "TODAY'S TRADING UPDATE\n\n✓✓ APARINDS - 2320 TO 2368👍👍\n(48 POINTS BTST)\n\n✓✓ PNBHOUSING - 600 TO 607👍👍\n(7 POINTS BTST)\n\n✓✓ ADANIENT -1372 TO 1580👍👍\n(200 POINTS SHORT TERM)\n\n✓✓ SBIN MARCH FUTURES - 530 TO 538👍👍\n(8 POINTS SHORT TERM)\n\n✓✓ CUMMINSIND MARCH FUTURES - 1588 TO 1612👍👍\n(24 POINTS SHORT TERM)\n\n\nTHAT'S ALL FROM TODAY 👍👍", 'BTST CANDIDATE\n\nATULAUTO AT 355', 'BTST CANDIDATE\n\nADANIENT AT 1575', 'BTST CANDIDATE\n\nMARUTI MARCH FUTURES AT 8799', 'CUMMINSIND MARCH FUTURES\n\n\n1604\n\nBOOK OR TRAIL STOP LOSS', '2 STOCK OPTIONS TRADE GIVEN IN BEGINNERS SERVICES!!\n\nBOTH MADE GOOD PROFITS', '', '', 'SBIN ALMOST TARGET 2 TAKEN\n\n\n538\n\nBOOK PROFITS OR TRAIL STOP LOSS', "MEMBER'S LOOKING TO JOIN SHORT TERM EQUITY SERVICES CAN MAKE PAYMENT HERE\n\n\nUSE COUPON CODE\n\nSPECIAL20\n\nTO GET FLAT 20% OFF!👍👍", 'https://rpy.club/g/75WAelBONI', 'SHORT TERM EQUITY\n\nBUY CCL\n\nCMP 564\n\nTARGET 575,590,620+\n\nSTOP LOSS 530', 'SBIN  MARCH FUTURES 534👍👍', 'ADANIENT 1511\n\nTARGET 2 TAKEN!', 'ADANIENT 1484👍👍', 'ADANIENT TARGET 1 TAKEN AT 1450\n\nBOOK PROFITS OR TRAIL STOP LOSS!', 'PNBHOUSING 603👍👍', 'APARINDS 2329\n\nBOOK PROFITS HERE!!👍👍', 'GOOD MORNING👍👍', 'BTST CANDIDATE\n\nAPARINDS AT 2320', 'CRISIL ALL TARGETS ACHIEVED AT 3440👍👍', 'BTST CANDIDATE\n\nPNBHOUSING AT 600', '1393👍👍', 'LAST 2 SEATS👍👍', "TODAY'S BANKNIFTY TRADE\n\n445 TO 550👍👍", '', '', "BUMPER MONTH END OFFER\n\nYEARLY MEMBERSHIP AT 7000\n\nLIFETIME MEMBERSHIP AT 9999\n\n\n\nOFFER VALID FOR FIRST 5 MEMBER'S ONLY👍👍\n\nONCE 5 MEMBER'S ARE DONE LINK WILL BE REVOKED AUTOMATICALLY👍👍", 'https://rpy.club/g/7RQ445iB2o', "MEMBER'S LOOKING TO JOIN SHORT TERM EQUITY SERVICES CAN MAKE PAYMENT HERE\n\n\nUSE COUPON CODE\n\nSPECIAL20\n\nTO GET FLAT 20% OFF!👍👍", 'https://rpy.club/g/75WAelBONI', 'SHORT TERM EQUITY\n\nBUY ADANIENT AT\n\n1372\n\nTARGET 1450,1500,1550+\n\nSTOP LOSS AT 1300', '1594👍👍', 'SHORT TERM FUTURES\n\nBUY CUMMINSIND MARCH FUTURES\n\nCMP 1588\nTARGET 1600,1620,1650+\n\nSTOP LOSS AT 1555', '682👍👍', "MEMBER'S LOOKING TO JOIN OUR INDEX OPTIONS SERVICES CAN MAKE PAYMENT HERE\n\n\nUSE COUPON CODE\n\nSPECIAL20 \n\nTO GET FLAT 20% OFF ON ALL DURATIONS 👍👍", 'https://rpy.club/g/7RQ445iB2o', '40000 CE\n\n400 TO 470👍👍', "TODAY'S INDEX TRADE", "MEMBER'S LOOKING TO JOIN SHORT TERM EQUITY SERVICES CAN MAKE PAYMENT HERE\n\n\nUSE COUPON CODE\n\nSPECIAL20\n\nTO GET FLAT 20% OFF!👍👍", 'https://rpy.club/g/75WAelBONI', 'BTST CANDIDATE\n\nSURYAROSNI AT 680', '3350👍👍', 'SHORT TERM EQUITY\n\nBUY CRISIL\n\nAROUND 3330\n\nTARGET 3360,3390,3400+\n\nSTOP LOSS AT 3270', 'SHORT TERM FUTURES\n\nBUY SBIN MARCH FUTURES\n\nCMP 530\n\nTARGET 535,540,545+\n\nSTOP LOSS 520', '', 'FINCABLES 716👍👍', 'POLYCAB 3095👍👍', 'BUMPER OFFERS ON INDEX OPTIONS SERVICES\n\nYEARLY MEMBERSHIP AT 7000\n\nLIFETIME MEMBERSHIP AT 9999\n\nLIMITED PERIOD OFFER👍👍', 'https://rpy.club/g/7RQ445iB2o', 'TRADE GIVEN IN INDEX OPTIONS\n\nIN THIS CHOPPY MARKET! WAS ABLE TO CAPTURE AROUND 60 POINTS 👍👍', '', '1615👍👍\n\nCUMMINSIND MARCH FUTURES', 'BDL 982👍👍', 'POWERMECH 2119👍👍', 'RAYMOND 1330👍👍', "TODAY'S TRADING UPDATE\n\n✓✓ PERSISTENT - HOLDING👍👍\n\n✓✓ GNA- 919 TO 936👍👍\n(17 POINTS BTST)\n\n✓✓ BFINVEST - 416 TO 430👍👍\n(14 POINTS BTST)\n\n✓✓ CUMMIN ...
# {'channel_url': 'https://t.me/JackpotTradeX', 'message_list': ['100 To 170 💥💥💥💥💥💥\n\n70% Return In Single Trade 🚨\n\nPower Of VIP MEMBERSHIP 😎', "02 MAR  : Today's Jackpot BankNifty 💥💥\n\nEasy to Execute ✅\n\nSimple To Enter ✅\n\nEasy to Book Profits  ✅\n\nSend Hii 👉 @Queries_JackpotTradeX", 'Top Looser Today : 02 MAR 📍', 'Top Gainers Today : 02 MAR 🚀', "𝘿𝙤𝙣'𝙩 𝙢𝙞𝙨𝙨 𝙏𝙤𝙙𝙖𝙮 𝙅𝙖𝙘𝙠𝙥𝙤𝙩 Expiry 𝘾𝙖𝙡𝙡𝙨 💥💥\n\nSend a Hii.. 👇\n@Queries_JackpotTradeX", "🔸 NIFTY AT DAY'S LOW", 'Quick Stock & Index Updates 📊\n\n🔹 ADANI F&O STOCKS RECOVERED\n\n🔸IT STOCKS UNDER PRESSURE\n\n🔹TITAGARH WAGONS UP 7 %\n\n🔸BHEL UP 3 %\n\n🔹RVNL UP 10 %\n\n🔸ADANI ENT 4 % CUT\n\n🔹ADANI PORT FLAT\n\n🔹ADANI GREEN 5 % UPPER FREEZE\n\n🔸ADANI TRANSMISSION UP 3 %\n\n🔹ADANI POWER 5 % UPPER FREEZE\n\n🔹 NIFTY OPEN 30 PTS GAP DOWN OPENING', '✅ EQUITY INTRADAY ✅\n\nBUY CRISIL ABOVE 3460\nTGT 3470 , 3483 , 3497', '✅ EQUITY INTRADAY ✅\n\nBUY PVR ABOVE 1561\nTGT 1567 , 1575 , 1583', '🔹 VEDANTA', 'Nifty on Last Trading Session 🔻\n\n Adani Enterprises, Hindalco Industries, UPL, SBI and Axis Bank were among the biggest gainers on the Nifty. On the other hand, Britannia Industries, Power Grid Corporation, Cipla, BPCL and SBI Life Insurance lost the most.', "👉 WEEKLY\xa0EXPIRY BIG CHANCE TO EARN BIG PROFIT 💯🤑🤑\n\nDON'T MISS TODAY'S ZERO TO HERO JACKPOT CALLS 🚀\n\n🔥 MONEY DOUBLE 💯\n\nJoin fast Send a Hii.. 💥\n@Queries_JackpotTradeX", 'STOCK IN ACTION : MAR 2 ♨️', '🔸 Nifty 50 to open lower, Asian shares in red', 'Stock In News : Mar 2 ♨️\n\nBajaj Finserv, AXIS BANK, HAL, Bharat Forge, & Delhivery', 'MAR 2\xa0 : Nifty Expected a Negative Start.', "Good Morning Trader's 👨\u200d💻😎", '', '', "Don't Miss #Expiry Trade  📊\nTomorrow\n\nTomorrow Expiry Means Low Capital investment High Double Profits 🔥🔥🔥\n\nHigh Accuracy /Reward 🥳🥳\n\n@1999 Offer Price ✅\n\nSend a Hii.. 👇\n@Queries_JackpotTradeX", "Big information 📣📣♨️🔥\n\nTomorrow bank nifty 600-700++ points Movement 〽️\n\nSpecial EXPIRY Jackpot calls 💕💕\n\nSend A Hii.. 👇\n@Queries_JackpotTradeX \n\nDON'T MISS...🙈🙈🙈\n\nRECOVER YOUR FEE'S IN 1 DAY\n\n#Jackpot #trade ⚡⚡", '', '', '', '', '', '', '', '', '', '', '', "NAVINFLUOR Today's High 4233🏌️\u200d♂️🏌️\u200d♂️\n🚀🚀🚀\n\nALL Targets Hits Here. 🤝", '', 'Booked Good Profit of ₹11,300++ Profit in 1st Trade Today.🤠🤠🎉🎉\n\n@1999  For 1 Months\n\nSend a Hii.. 👇👇\n@Queries_JackpotTradeX', "🔸 NIFTY AT DAY'S HIGH ⬆️", "Big Move coming In 2nd half 🛑🛑\n\n#BankNifty 🔥\n\n@1999 Offer Price ✅\n\nSend a Hii for next jackpot trade.. Don't Miss 👇👇\n@Queries_JackpotTradeX", "01 MAR  : Today's Jackpot BankNifty 💥💥\n\nEasy to Execute ✅\n\nSimple To Enter ✅\n\nEasy to Book Profits  ✅\n\nSend Hii 👉 @Queries_JackpotTradeX", 'Recover Your Losses Today ✅\n\nSend a Hii.. 👇\n@Queries_JackpotTradeX', 'Top Gainers Today : 01 MAR 🚀', 'Top Looser Today : 01 MAR 📍', 'NAVINFLUOR 🚀 UNSTOPPABLE 🔥\n🔒 Now @ 90 Pts\n\n✅ 4114 TO 4205 ✈️💰\n🎯 All Target achieved 🎯\n\n🥁  Unbelievable Returns in Just 1 Day\n\n✔️ # Power Of VIP MEMBERSHIP (Paid Group)\n\nSend a Hii.. 👇👇\n\n@Queries_JackpotTradeX', '✅ EQUITY INTRADAY ✅\n\nBUY NAVINFLUOR ABOVE 4166\nTGT 4178 , 4190 , 4215', 'STOCK IN ACTION : MAR 1 ♨️', 'Nifty on Last Trading Session 🔻\n\n Nifty50, ended at 17,303, down 89 points or 0.51%', 'Our Official Contact Info  ✅\n\nSend a Hii.. 👇\n@Queries_JackpotTradeX', 'Stock In News : Mar 1 ♨️\n\nDelhivery, Paytm, SBI, Zydus Life, NTPC, RIL', '28 FEB\xa0 : Nifty Expected a Negative Start.', "Good Morning Trader's 👨\u200d💻😎", '', '', 'Huge Public Demand For @1999 Monthly Plans 🤩\n\n🔴 @1999 Plan Can End Anytime!\n\nSend a Hii..\n👇👇👇👇\n@Queries_JackpotTradeX', '🚨 VIP SUBSCRIPTION DETAILS & BENIFITS 👇\n\nBenifits For a VIP MEMBER 👇🏻\n\n✅ Early Entry to Paid Subscribers\n✔️ Advance watchlist\n✔️ 2-4 Intraday BankNifty/Nifty\n✔️ 2-3 Trades Equity Intraday \n✔️ Early Entry\n✔️ Stoploss \n✔️ Guide when to Enter\n✔️ Guide When to Exit\n✔️ We keep it Simple & Easy \n✔️ Live Market Support\n\n🔔 Contact Us Now To Join 👇🏻⚡\n\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 @Queri ...
# {'channel_url': 'https://t.me/intraday_tradex', 'message_list': ['✅ BANKNIFTY 40900 PE MADE A HIGH OF 360\n\n2ND TARGET HITS 💰💰💰💰💰', '360 ✅✅✅', '💠 BANKNIFTY 40900 PE\n\nBUY ABOVE 300 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 320\n🎯 2ND TARGET: 350\n🎯 3RD TARGET: 390', '💠 BANKNIFTY 40200 CE\n\nBUY ABOVE 440 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 460\n🎯 2ND TARGET: 490\n🎯 3RD TARGET: 530', '', 'Good morning traders ☀️☀️☀️ \n\nHope Have a profitable day\xa0 🔥🔥🔥', '💠 Premium Membership Details\n\nMake Consistent Daily Profits with us\n\n🔰 Benefits Of Premium Membership\n\n❇️ 2-3 F&O [ NIFTY/BANKNIFTY/ Stock Options] Calls Per Day\n\n❇️ 2-4 Equity Cash Calls Per Day\n\n❇️ 4-9 Swing Calls Per Month\n\n❇️ Portfolio Advise \n\n🔰 1 MONTH FEE: RS 5000\n\n🔔 For Joining Contact : @Team_IntradayTradeX', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members\n👇👇👇👇', '✅ BANKNIFTY 39900 CE MADE A HIGH OF 620\n\nALL TARGETS HITS 💰💰💰💰💰', '620 ✅✅✅', '💠 BANKNIFTY 39900 CE\n\nBUY ABOVE 495 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 515\n🎯 2ND TARGET: 540\n🎯 3RD TARGET: 570', '', 'Good morning traders ☀️☀️☀️ \n\nHope Have a profitable day\xa0 🔥🔥🔥', '💠 Premium Membership Details\n\nMake Consistent Daily Profits with us\n\n🔰 Benefits Of Premium Membership\n\n❇️ 2-3 F&O [ NIFTY/BANKNIFTY/ Stock Options] Calls Per Day\n\n❇️ 2-4 Equity Cash Calls Per Day\n\n❇️ 4-9 Swing Calls Per Month\n\n❇️ Portfolio Advise \n\n🔰 1 MONTH FEE: RS 5000\n\n🔔 For Joining Contact : @Team_IntradayTradeX', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members\n👇👇👇👇', '✅ BANKNIFTY 39900 CE MADE A HIGH OF 632\n\nALL TARGETS HITS 💰💰💰💰💰', '632 ✅✅✅', '💠 BANKNIFTY 39900 CE\n\nBUY ABOVE 530 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 550\n🎯 2ND TARGET: 580\n🎯 3RD TARGET: 620', '', 'Good morning traders ☀️☀️☀️ \n\nHope Have a profitable day\xa0 🔥🔥🔥', '💠 Premium Membership Details\n\nMake Consistent Daily Profits with us\n\n🔰 Benefits Of Premium Membership\n\n❇️ 2-3 F&O [ NIFTY/BANKNIFTY/ Stock Options] Calls Per Day\n\n❇️ 2-4 Equity Cash Calls Per Day\n\n❇️ 4-9 Swing Calls Per Month\n\n❇️ Portfolio Advise \n\n🔰 1 MONTH FEE: RS 5000\n\n🔔 For Joining Contact : @Team_IntradayTradeX', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members\n👇👇👇👇', '💠 BANKNIFTY 40200 PE\n\nBUY ABOVE 400 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 420\n🎯 2ND TARGET: 450\n🎯 3RD TARGET: 490', '💠 BANKNIFTY 40200 PE\n\nBUY ABOVE 446 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 465\n🎯 2ND TARGET: 490\n🎯 3RD TARGET: 520', '', 'Good morning traders ☀️☀️☀️ \n\nHope Have a profitable day\xa0 🔥🔥🔥', '💠 Premium Membership Details\n\nMake Consistent Daily Profits with us\n\n🔰 Benefits Of Premium Membership\n\n❇️ 2-3 F&O [ NIFTY/BANKNIFTY/ Stock Options] Calls Per Day\n\n❇️ 2-4 Equity Cash Calls Per Day\n\n❇️ 4-9 Swing Calls Per Month\n\n❇️ Portfolio Advise \n\n🔰 1 MONTH FEE: RS 5000\n\n🔔 For Joining Contact : @Team_IntradayTradeX', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members\n👇👇👇👇', '✅ BANKNIFTY 40100 PE MADE A HIGH OF 347\n\n1ST TARGET HITS 💰💰💰💰💰', '347 ✅✅✅', '💠 BANKNIFTY 39900 CE\n\nBUY ABOVE 525 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 545\n🎯 2ND TARGET: 575\n🎯 3RD TARGET: 610', '💠 BANKNIFTY 40100 PE\n\nBUY ABOVE 301 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 325\n🎯 2ND TARGET: 355\n🎯 3RD TARGET: 400', '💠 BANKNIFTY 40100 PE\n\nBUY ABOVE 301 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 325\n🎯 2ND TARGET: 355\n🎯 3RD TARGET: 390', '💠 BANKNIFTY 39900 CE\n\nBUY ABOVE 546 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 565\n🎯 2ND TARGET: 595\n🎯 3RD TARGET: 630', '💠 BANKNIFTY 40600 PE\n\nBUY ABOVE 522 ✅\n\nSL: PAID \n\n🎯 1ST TARGET: 540\n🎯 2ND TARGET: 570\n🎯 3RD TARGET: 610', '', 'Good morning traders ☀️☀️☀️ \n\nHope Have a profitable day\xa0 🔥🔥🔥', '💠 Premium Membership Details\n\nMake Consistent Daily Profits with us\n\n🔰 Benefits Of Premium Membership\n\n❇️ 2-3 F&O [ NIFTY/BANKNIFTY/ Stock Options] Calls Per Day\n\n❇️ 2-4 Equity Cash Calls Per Day\n\n❇️ 4-9 Swing Calls Per Month\n\n❇️ Portfolio Advise \n\n🔰  ...
# {'channel_url': 'https://t.me/tradephoenix_stocks', 'message_list': ['305++✅✅', '✅ 2Nd Target Hit', '290++✅✅', '✅ 1St Target Hit', '270++✅✅', '265++✅✅', '260++✅✅', '✅ BUY BANKNIFTY 02 MAR 40400 CE\n\nABOVE - 250\n\nTARGETS- 270/290/310', '✅ BUY BANKNIFTY 02 MAR 40800 PE\n\nABOVE - 280\n\nTARGETS- 300/320/340', '220++✅✅', '✅ BUY BANKNIFTY 02 MAR 40600\xa0 CE\n\nABOVE - 210\n\nTARGETS- 230/350/370', 'Stock Market Live Updates: SGX Nifty signals a negative start; Asian shares trade mixed', 'Good Morning 🌞🌞🌞', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '⚜️ PREMIUM MEMBERSHIP ⚜️\n\n✅ Capital Required: 20k Minimum \n\n\n🔰🔰 ADVANTAGES & BENEFITS OF PREMIUM SERVICE ✅\n\n✅ BANKNIFTY OPTIONS CALLS\n\n✅ STOCK OPTIONS CALLS\n\n✅ PROPER TARGET & STOPLOSS\n\n✅ GUIDANCE ABOUT WHEN TO ENTRY & EXIT\n\n✅ LIVE MARKET SUPPORT\n\n✅ HIGH ACCURACY\n\n✅ 1 OPEN POSITION AT A TIME\n\n✅ SAFE TRADE ONLY\n\n\n🎯 Daily 2 To 4 options call\n\n🎯 20k Capital required & Maximum depend on you \n\n🎯 We provide Calls with more than 90% accuracy\n\n🎯 When Buy, When Hold, when Trailing & Modify stop loss, when Book profit and when Exit\nAll Updates & Guidance 👍\n\n\n♻️ 1 MONTH FEE: RS 5000\n\n🔶 For joining contact: @Team_TradePhoenix', '✅ All Targets Hit', '330++✅✅', '✅ 2Nd Target Hit', '310++✅✅', '305++✅✅', '✅ 1St Target Hit', '290++✅✅', '✅ BUY BANKNIFTY 02 MAR 40300 CE\n\nABOVE - 270\n\nTARGETS- 290/310/330', 'Pre-open session: Sensex rises 70 points; Nifty above 17,360', 'Good Morning 🌞🌞🌞', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '⚜️ PREMIUM MEMBERSHIP ⚜️\n\n✅ Capital Required: 20k Minimum \n\n\n🔰🔰 ADVANTAGES & BENEFITS OF PREMIUM SERVICE ✅\n\n✅ BANKNIFTY OPTIONS CALLS\n\n✅ STOCK OPTIONS CALLS\n\n✅ PROPER TARGET & STOPLOSS\n\n✅ GUIDANCE ABOUT WHEN TO ENTRY & EXIT\n\n✅ LIVE MARKET SUPPORT\n\n✅ HIGH ACCURACY\n\n✅ 1 OPEN POSITION AT A TIME\n\n✅ SAFE TRADE ONLY\n\n\n🎯 Daily 2 To 4 options call\n\n🎯 20k Capital required & Maximum depend on you \n\n🎯 We provide Calls with more than 90% accuracy\n\n🎯 When Buy, When Hold, when Trailing & Modify stop loss, when Book profit and when Exit\nAll Updates & Guidance 👍\n\n\n♻️ 1 MONTH FEE: RS 5000\n\n🔶 For joining contact: @Team_TradePhoenix', '✅ 1St Target Hit', '310++✅✅', '✅ BUY BANKNIFTY 02 MAR 40400 PE\n\nABOVE - 290\n\nTARGETS- 310/330/350', '✅ BUY BANKNIFTY 02 MAR 40400 PE\n\nABOVE - 300\n\nTARGETS- 320/340/350/360', 'Pre-open session: Sensex rises 50 points; Nifty above 17,390', 'Good Morning 🌞🌞🌞', '⚜️ PREMIUM MEMBERSHIP ⚜️\n\n✅ Capital Required: 20k Minimum \n\n\n🔰🔰 ADVANTAGES & BENEFITS OF PREMIUM SERVICE ✅\n\n✅ BANKNIFTY OPTIONS CALLS\n\n✅ STOCK OPTIONS CALLS\n\n✅ PROPER TARGET & STOPLOSS\n\n✅ GUIDANCE ABOUT WHEN TO ENTRY & EXIT\n\n✅ LIVE MARKET SUPPORT\n\n✅ HIGH ACCURACY\n\n✅ 1 OPEN POSITION AT A TIME\n\n✅ SAFE TRADE ONLY\n\n\n🎯 Daily 2 To 4 options call\n\n🎯 20k Capital required & Maximum depend on you \n\n🎯 We provide Calls with more than 90% accuracy\n\n🎯 When Buy, When Hold, when Trailing & Modify stop loss, when Book profit and when Exit\nAll Updates & Guidance 👍\n\n\n♻️ 1 MONTH FEE: RS 5000\n\n🔶 For joining contact: @Team_TradePhoenix', '', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '✅ All Targets Hit', '420++✅✅', '✅ 2Nd Target Hit', '390++✅✅', '✅ 1St Target Hit', '370++✅✅', '✅ BUY BANKNIFTY 02 MAR 39900 CE\n\nABOVE - 350\n\nTARGETS- 370/390/410', '✅ BUY BANKNIFTY 02 MAR 39800 PE\n\nABOVE - 300\n\nTARGETS- 320/340/360', 'Stock Market Live Updates: SGX Nifty signals a negative start; Asian shares trade lower', 'Good Morning 🌞🌞🌞', '⚜️ PREMIUM MEMBERSHIP ⚜️\n\n✅ Capital Required: 20k Minimum \n\n\n🔰🔰 ADVANTAGES & BENEFITS OF PREMIUM SERVICE ✅\n\n✅ BANKNIFTY OPTIONS CALLS\n\n✅ STOCK OPTIONS CALLS\n\n✅ PROPER TARGET & STOPLOSS\n\n✅ GUIDANCE ABOUT WHEN TO ENTRY & EXIT\n\n✅ LIVE MARKET SUPPORT\n\n✅ HIGH ACCURACY\n\n✅ 1 OPEN POSITION AT A TIME\n\n✅  ...
# {'channel_url': 'https://t.me/kingline_stocks', 'message_list': ['💚 NIFTY 02 MARCH\xa017500 PE\n1ST TARGET HIT', '₹131 💚💚', '#Nifty 02 Mar 17500 PE\n\nBuy at ₹115 to ₹118\n\n✅ Target of ₹130 & ₹150\n\nSL: PAID🔒', '#BankNifty 02 Mar 40300 CE\n\nBuy at ₹420 to ₹430\n\n✅ Target of ₹470 & ₹500\n\nSL: PAID🔒', 'Stocks to Watch: Adani Group, Axis Bank, Bajaj Finserv, Airtel, Marico, HAL', 'Good Morning 💰💰💰', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '🔥 Premium Members are Booking Huge profits Daily !\n\nHandhold Support is provided to Our Premium Members 😎\n\nProper Updates on Booking Profits 🤩\n\n\n✅ 2-4 Daily Bank Nifty Calls\n\n✅ 1-2 Daily Stock Options Calls\n\n✅ 1-2 Daily Equity Cash Calls\n\n✅ Swing Call\n\n✅ F&O Calls\n\n✅ Portfolio Advise\n\n✅✅  Charges: Rs 5000 For a Month\n\n\n🔔  Contact: @Kingline_Support', '💚 BANKNIFTY 02 March 40200 CE \n\nALL TARGETS HIT\n\n✅ 80 Points Booked', '₹490 💚💚', '#BankNifty 02 Mar 40200 CE\n\nBuy at ₹405 to ₹410\n\n✅ Target of ₹440 & ₹470\n\nSL: PAID🔒', 'Day trading guide: Tata Power, IEX, Ashok Leyland among 7 stocks to buy today - March 1', 'Good Morning 💰💰💰', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '🔥 Premium Members are Booking Huge profits Daily !\n\nHandhold Support is provided to Our Premium Members 😎\n\nProper Updates on Booking Profits 🤩\n\n\n✅ 2-4 Daily Bank Nifty Calls\n\n✅ 1-2 Daily Stock Options Calls\n\n✅ 1-2 Daily Equity Cash Calls\n\n✅ Swing Call\n\n✅ F&O Calls\n\n✅ Portfolio Advise\n\n✅✅  Charges: Rs 5000 For a Month\n\n\n🔔  Contact: @Kingline_Support', '₹110 💚💚', '#Nifty 02 Mar 17400 CE\n\nBuy at ₹90 to ₹95\n\n✅ Target of ₹125 & ₹150\n\nSL: PAID🔒', "Stocks to Watch: Adani Group, Zee, SpiceJet, Vodafone Idea, Dr Reddy's, Wipro", 'Good Morning 💰💰💰', '🔥 Premium Members are Booking Huge profits Daily !\n\nHandhold Support is provided to Our Premium Members 😎\n\nProper Updates on Booking Profits 🤩\n\n\n✅ 2-4 Daily Bank Nifty Calls\n\n✅ 1-2 Daily Stock Options Calls\n\n✅ 1-2 Daily Equity Cash Calls\n\n✅ Swing Call\n\n✅ F&O Calls\n\n✅ Portfolio Advise\n\n✅✅  Charges: Rs 5000 For a Month\n\n\n🔔  Contact: @Kingline_Support', '', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '₹170 💚💚', '#Nifty 02 Mar 17350 CE\n\nBuy at ₹150 to ₹155\n\n✅ Target of ₹185 & ₹215\n\nSL: PAID🔒', 'Stocks to Watch: Adani Green, Vodafone, Adani Ports, Paytm, IndiGo, ABB India', 'Good Morning 💰💰💰', '🔥 Premium Members are Booking Huge profits Daily !\n\nHandhold Support is provided to Our Premium Members 😎\n\nProper Updates on Booking Profits 🤩\n\n\n✅ 2-4 Daily Bank Nifty Calls\n\n✅ 1-2 Daily Stock Options Calls\n\n✅ 1-2 Daily Equity Cash Calls\n\n✅ Swing Call\n\n✅ F&O Calls\n\n✅ Portfolio Advise\n\n✅✅  Charges: Rs 5000 For a Month\n\n\n🔔  Contact: @Kingline_Support', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '💚 BANKNIFTY 02 March 40400 CE \n\nALL TARGETS HIT\n\n✅ 70 Points Booked', '₹320 💚💚', '#BankNifty 02 Mar 40400 CE\n\nBuy at ₹245 to ₹250\n\n✅ Target of ₹280 & ₹310\n\nSL: PAID🔒', 'Stocks to Watch: Zee, HDFC Bank, LIC, Adani Transmission, Infosys', 'Good Morning 💰💰💰', '', '', '', '', '', '', '', '', '', '', 'Profit Booked by our Premium Group Members.\n⬇️⚜⬇️⚜⬇️⚜⬇️', '🔥 Premium Members are Booking Huge profits Daily !\n\nHandhold Support is provided to Our Premium Members 😎\n\nProper Updates on Booking Profits 🤩\n\n\n✅ 2-4 Daily Bank Nifty Calls\n\n✅ 1-2 Daily Stock Options Calls\n\n✅ 1-2 Daily Equity Cash Calls\n\n✅ Swing Call\n\n✅ F&O Calls\n\n✅ Portfolio Advise\n\n✅✅  Charges: Rs 5000 For a Month\n\n\n🔔  Contact: @Kingline_Support', '💚 BANKNIFTY 23 FEBRUARY\xa0 39800 PE \n\nALL TARGETS HIT\n\n✅ 80 Points Booked', '₹180 💚💚', '💚 BANKNIFTY 23 FEBRUARY\xa039800 PE\n1ST TARGET HIT', '₹130 💚💚', '#BankNifty 23 Feb 39800 PE\n\nBuy at ₹100 to ₹105\n\n✅ Target of ₹130 & ₹160\n\nSL: PAID🔒', ' ...
# {'channel_url': 'https://t.me/moneygainers3', 'message_list': ['622✈️', '#lal path\nClosing above blue line \nBtst trade', '', 'Nice scalp✈️', 'Already told you \n40600 per tha tab \n\nNow below 40400\n\nHope everyone made good profit ✈️', '608 to 617✈️', '', 'Jinko risk lena hein\nBuy power grid 230 ce @1.5\nStoploss:- 0.9\nTarget:- 2/2.5/3+\n\nHighly risky \nOnly affordable', '39✈️✈️', '', '', '', 'Indusind \nLooks good for swing\nCmp 1095-1100\nTarget:- 1130/50/70+\nSl:- 1065\n\nKeep eye @200 ema support', 'This setup give me 100 points', '', 'Escorts \nCmp 2086\nClosing above 2138-2140\nBack to bulls', 'Jublfood \nTomorrow on radar\nKeep eye above 445\n 450/453/457+', 'Enjoy 🥳', '', 'Our zone is their that’s why up 😎', 'Again circuit', 'Need close above 40550 for more big move', 'On smaller time frame', 'BANK NIFTY \nALL YOU WANT \n\n@support zone and near 200 dma \nClosing below 39430 \nBear gear on\n\nAbove 40400 closing need', 'VEDANTA: Vedanta Resources prepays all of its debt due till March 2023 and has deleveraged by $2 billion in the past 11 months - mint', 'INFY \n1490-1480', 'Support zone :- 29240', 'Portfolio stock', '', '', 'Yesterday update \nToday see 🥳\n\n\nThat’s the power of knowledge \nHard work \n\n\nChart sabkuch batayega \n😎', '', 'BAJAJ AUTO \nCrucial support @3590-3450', 'Bajaj finance \nCmp 6208-6210\nExpecting 6252/6300/6345+', 'JSW STEEL \n@support area and bounce today \n\nBelow 660 closing \nMay see 630', 'TATA STEEL 105-106 \nSl:- 101', 'Second Target done 🥈', '', '', 'It always works 🤘🏻🙈', '', '', '', 'Need this \nTab india me jan ayee \n\n😅', 'PVR \nFALL AS EXPECTED', '', 'Given on tuesday', '15 to 19.70', 'Adani green back to back circuit on crucial support now', 'Gaya', 'Down 1.5 %', 'Lt\nImportant trendline \nTomorrow sell below yesterday ‘s low', 'Dekhlo\nS chand ko \n\nChandd tak pochne vala hein', '', 'And adani ka toh bat hi mat pucho \nAs old members no how much i invested in adani stocks\n\nBut seriosuly itna fall hone keh bad bhi ham green me hein\n\nAnd .,my top pick up is\n\nAdani port\nAdani power\nAmbuja\nAdanient (600-900 don’t miss) \nAwl', 'Let’s see', 'CRUCIAL TRENDLINE SUPPORT', 'FOR PREMIUM MEMBERSHIP \nCONTACT us :- @money_gainers', 'ONE STOCK GIVEN ON OUR PREMIUM MEMBERS AND FREE WHATSAPP GROUP\n\n4 days ago \n\nIn 4 days it zoming 25% return\n\nAnd split in ratio 13:10\n\nExtra benefit\n\nAiming for 200-300% return 👌🏻', 'Dekhlo hamne bol diya zone matlab ki usko vaha sein uper ana hoga ✈️✈️✈️\n\n149 to 155+', 'Now @33+', 'Given when here update', 'Kya dekh rahe hein app.???', '', '', 'New low🧐', '', 'Sl below 3170', '', 'As per NSE Data, 38 Lakh clients have *left Stock Market* in the last 6 months.\n\nI think more will leave.\n\nThe "lockdown traders" must have seen the reality of the stock market and what it means to stay for the long term here.\n\nSerious trading is difficult, like any profession is.\n\n\n*Quick look at the NSE Average Turnover -*\n\nCash:\n\nDaily Turnover Apr 22: INR 73220 Crore\nDaily Turnover Jan 23: INR 22829 Crore\n\nDrop of 69%! 😱😱\n\nOptions:\n\nDaily Turnover Feb 22: INR 90 Lakh Crore\nDaily Turnover Jan 23: INR 1.55 Crore Crore\n\nJump of 71%!!', 'IRB \nSPLIT KEH BAD VALA POINTS \n\nIF MILE 25 -18 levels then buy 👍\nWith sl :- 14 \n\nHolding periods 2 years\n\nRisky', '', '', 'Don’t get confused in our \npremium groups\n\nREPUBLIC DAY OFFER \n\n1:- option calls+ positional \n      = @999 per month \n\n2 :- new service added \nOnly cash call+ positional call\n:- @ 1500 per year \n\n\nDiscount offer you don’t have to miss:- \n\n2:- SHORT TERM +long term\n+ SWING + INVESTMENT CALL + fundamental call + INTRADAY +\nMULTIBAGGER (penny stock)\n\nAll @just 1500/- per YEAR \nYES 1500/- per year only \n\n(Not included option call) \n\nHurry up offer closing soon \n\nContact :- @money_gainers', '176 to 200+🥳', '895-900 to 3100 levels ❤️\u200d🔥\n\nWhat u want', '', '', '', '17.75 to 19.90 \n900 lot size\n2,000 ₹ + Profit ❤️', '', '', '', '', 'Also this  ...
# {'channel_url': 'https://t.me/nifty_50_stocks', 'message_list': ['', '', '', '', 'Stocks to Watch: Adani Group, Axis Bank, Bajaj Finserv, Airtel, Marico, HAL', 'Good Morning Traders\n\nTO START MAKING MORE MONEY FROM TRADING, SEND ME A MESSAGE HERE: @TeamNifty50\n\n\n\nNOTE: All stock analysis which we provide are for learning purpose ONLY.\n\nPLEASE CONSULT YOUR FINANCIAL ADVISOR', "Black Diamond students added more money into their bank accounts…WOW\n\nYou don’t even need a computer… You can do everything on your smart phone or tablet.\n\nI'm going to give you every move I make in my trading step by step…\n\nSo that you can manage the trade like a PRO by simply copying and pasting what I am doing\n\nWhether you want to grow your trading account month after month and turn it into a fortune over time…\n\nOr you just need to make an extra ₹25k, ₹75k, or ₹125k a month to pay bills and keep up with inflation…\n\nAll you have to do...is get into my membership (black diamond)...and take a step\n\nEarn While You Learn!\n\nEnroll Now ⇨ @TeamNifty50", '', '', '', '', '', '', '', "⚜ Black Diamond Profits ⚜\n\nBlack Diamond Members are booking Great Profits DAILY\n\n🔶 TODAY'S PROFIT BOOKED 👇👇👇", 'What Is Black Diamond Membership All About?\n\nInside this membership, I will address…\n\n⇨ \xa0How you can start your career as a trader, while completely aligned with your JOBS for some time\n\n⇨ \xa0If you don’t have time for confusing analysis or technical charts, this membership is for YOU!\n\n⇨ \xa0You want to skillfully enter the stock market… but don’t know where to begin\n\n⇨ \xa0You can’t spot an early warning signal and END UP losing your capital more often\n\n⇨ \xa0Want to quit your job and get out of the 9 to 5 circle?\n\nHow about I tell you every SECRET OF TRADING… in my Black Diamond membership.\n\nIn fact, you don’t need any special skills at all to start making ₹₹₹ in the market\n\nAll you have to do is drop us a message here (@TeamNifty50) to register now.', '✅ ✅ DEEPAKNTR Both Targets Achieved\n\n🔥🔥🔥🔥🔥💰💰💰💰💰\n\n✅✅ TARGETS ACHIEVED: 1813, 1822\n\n✅✅ 18 Points Booked 🔥🔥\n\nCurrent High: 1853\n\n\nHuge Profit Booked 😁😁😁', '✅ ✅ GRASIM Both Targets Achieved\n\n🔥🔥🔥🔥🔥💰💰💰💰💰\n\n✅✅ TARGETS ACHIEVED: 1580, 1588\n\n✅✅ 16 Points Booked 🔥🔥\n\nCurrent High: 1598\n\n\nHuge Profit Booked 😁😁😁', '✅ ✅ CUMMINSIND Both Targets Achieved\n\n🔥🔥🔥🔥🔥💰💰💰💰💰\n\n✅✅ TARGETS ACHIEVED: 1582, 1590\n\n✅✅ 16 Points Booked 🔥🔥\n\nCurrent High: 1610.95\n\n\nHuge Profit Booked 😁😁😁', '✅ ✅ DIXON Both Targets Achieved\n\n🔥🔥🔥🔥🔥💰💰💰💰💰\n\n✅✅ TARGETS ACHIEVED: 2915, 2929\n\n✅✅ 29 Points Booked 🔥🔥\n\nCurrent High: 2994.25\n\n\nHuge Profit Booked 😁😁😁', "⚪ SRF NOT ACTIVATED\n\nMade a Low of 2184 \n\n(DIDN'T GOES BELOW 2180)", "This is what my students earned yesterday...\n\nI can help you with your goals...\n\nI can help you...write your cheque by learning how to multiply your income 10X times what you are currently earning...\n\nAnd this is what I teach in Black Diamond Membership…\n\nWhat if I guarantee you...that if you give me a chance to help you with my black membership…so you can earn more for your parent with your trading career...\n\nWOULD YOU GIVE ME A CHANCE TO DO THAT!\n\nDon't let your parents wait more...for the luxury of life...give me a chance to help you quit your 9 to 5 job...\n\nDrop us a message here (@TeamNifty50) AND GET YOURSELF IN!", '', '', '', '', '', 'Stocks to Watch: Adani Group, Paytm, SBI, Biocon, Vedanta, Delhivery', 'Good Morning Traders\n\nTO START MAKING MORE MONEY FROM TRADING, SEND ME A MESSAGE HERE: @TeamNifty50\n\n\n\nNOTE: All stock analysis which we provide are for learning purpose ONLY.\n\nPLEASE CONSULT YOUR FINANCIAL ADVISOR', "JOIN BLACK DIAMOND\n\nYou can't double your money by saving it...\n\nRemember, If you want to double your money...you have to invest in the right things.\n\nAnd the best investment is yourself.\n\nThe more you know...the more you earn.\n\n⦿ We are giving NIFTY, BANKNIFTY & EQUITY CALLS \n\n⦿ Calls one by one (wh ...
# {'channel_url': 'https://t.me/Banknifty_specials', 'message_list': ['', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40700PE @ 300 To 327\n.\n.\n.\n40200CE @ 270 To 293\n\n❤️❤️❤️❤️❤️', 'Bank Nifty\n.\n.\n.\n.\n40500 To 40370❤️❤️\n.\n.\nPrice Action Always Rock ...🔥', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40800PE\n.\n.\n.\n300 To 358 ❤️❤️❤️', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\nFINNIFTY 18200PE\n.\n.\n.\n190 To 205 ❤️❤️❤️', '40500 To 40441', 'Bank Nifty 🔥🔥 👆👆\n.\n.\n.\n.\nAny Doubt .....😁\n.\n.\n.\nOption Moving Fire 🔥🔥🔥', 'Bank Nifty \n.\n.\n.\nLoading @ 40500', 'Bank Nifty Not Break Mroning First 5 Min. candle !!!\n.\n.\n.\n150 Point Today Expiry Range !!', 'STOCK OPTION PLAYER JOIN OUR CHANNEL :👇\n\nhttps://t.me/Stockoptio_future\n\n97% High Accuracy', 'Bank Nifty Important Level \n.\n.\n.\n@ 40500', 'Bank Nifty \n.\n.\n.\nGood Above @ 40788', 'https://accounts.asthatrade.com/authentication/login?c=tmZq2\n\n\n👆 Open Free Demat Account in Asthe Trade !!\n\nBenefits For Option Trader !!\n\n5x Margin In Option Trading ✌️\n\nUse 20k @ Work 1Lakh✅✅\n\nAstha Me Aap ko Option Mein 5 Time Limit Milega !! Its good for option Trader ✌️', 'Good Morning', '🏆 PREMIUM SERVICE 🏆\n\n✅BANKNIFTY & NIFTYFIN OPTION\n✅OPTION & INTRADAY\n✅CAPITAL REQUIRED 10K To 20k\n✅DAILY PROFIT : 5K TO 15K\n✅ACCURACY 95% ++\n✅3 & 4 Calls Daily\n✅Msg Paid Whatsapp Broadcast Grp\n\n\n❤️For More Profitable Trade❤️\n📶Join premium Calls👇👇\n\n💹 Monthly Fees 4000/- Only 💹\n\nTo Join , send msg/Missed call\n\n👉https://wa.link/wd0xoz', 'Bank Nifty After 10 AM Trade Just 160/170 Point Range !!\n.\n.\n.\nWait For Breakout With Volume !!!', '40533 To 40635', 'Bank Nifty Eye On \n.\n.\n.\n.\n@ 40533', 'Good Morning', '🏆 PREMIUM SERVICE 🏆\n\n✅BANKNIFTY & NIFTYFIN OPTION\n✅OPTION & INTRADAY\n✅CAPITAL REQUIRED 10K To 20k\n✅DAILY PROFIT : 5K TO 15K\n✅ACCURACY 95% ++\n✅3 & 4 Calls Daily\n✅Msg Paid Whatsapp Broadcast Grp\n\n\n❤️For More Profitable Trade❤️\n📶Join premium Calls👇👇\n\n💹 Monthly Fees 4000/- Only 💹\n\nTo Join , send msg/Missed call\n\n👉https://wa.link/wd0xoz', '✍ DONE OF THE DAY ✍\n\n✅FINNIFTY 18200PE @ 215 To 285\n\n✅40400PE @ 330 To 415\n\n✅40100CE @ 305 To 371\n\n✅BNF @ 40200 To 40074\n\n✅Nifty @ 17333 To 17256\n\n✅FINNIFTY 18200PE @ 25 POINT SL', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40100CE\n.\n.\n.\n305 To 371 ❤️❤️❤️', 'Nifty 🔥🔥🔥\n.\n.\n.\n.\n17333 To 17256 ❤️❤️', 'Bank Nifty Panic 🩸🩸\n.\n.\n.\n.\n40200 To 40084 ❤️❤️🔥', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40400PE\n.\n.\n.\n330 To 386 ❤️❤️❤️', 'Read This Line 👆\n.\n.\n.\nPrice Action Trade 🔥🔥', 'FINNIFTY 18200PE\n.\n.\n.\n215 TO 255\n.\n.\n.\nALL TARGET DONE ❤️❤️❤️', 'Bank Nifty Below @ 40200 Panic Selling !!\n.\n.\n.\n.\n.\nBank Nifty Upside @ 40400 Short Covering Possible !!', 'Nifty Weak Below \n.\n.\n.\n.\n@ 17333', 'Bank Nifty\n.\n.\n.\n40211 To 40411\n.\n.\n.\nPremium Dcay Zone !!', 'BANK NIFTY CHART', 'Bank Nifty \n.\n.\n.\nWeak Below @ 40188', 'Keep Eye On Above @ 215 \n.\n.\n.\nTarget @ 227/239', 'FINNIFTY 18200PE Good Above @ 210\n.\n.\n.\n.\nSL @ 185', 'Bank Nifty Sustain Above @ 40411\n.\n.\n.\n.\nTarget : 40477/40533', 'BANK NIFTY\n.\n.\n.\n.\nKEEP EYE ON @ 40400 @ 40233', 'Good Morning', 'https://accounts.asthatrade.com/authentication/login?c=tmZq2\n\n\n👆 Open Free Demat Account in Asthe Trade !!\n\nBenefits For Option Trader !!\n\n5x Margin In Option Trading ✌️\n\nUse 20k @ Work 1Lakh✅✅\n\nAstha Me Aap ko Option Mein 5 Time Limit Milega !! Its good for option Trader ✌️', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40000CE\n.\n.\n.\n330 To 468 ❤️❤️❤️', 'Bank Nifty \n.\n.\n40188 To 40275 🔥', '325 To 343 ❤️❤️', '40200CE Buy Above @ 325\n.\n.\n.\nSL @ 296', '40188 To 40240 ❤️❤️', 'Bank Nifty Fire Move Above @ 40188', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40000PE\n.\n.\n.\n315 To 351❤️❤️❤️', 'PREMIUM GROUP 🔥🔥\n.\n.\n.\n40000CE\n.\n.\n.\n315 To 392❤️❤️❤️', '39888 To 39845', '39822 Near Small Support Zone !!', 'Bank Nifty 40000PE Good Above @ 340\n.\n.\n.\nSL @ 305', '40100CE Good Above @ 320\n.\n.\n.\nSL @ 288', 'Bank Nifty Keep Eye On \n.\n.\n.\n@ 39888', 'Bank Nifty\n.\n.\n.\n400 ...
# {'channel_url': 'https://t.me/traderssquad', 'message_list': ['Sl 148', 'Reason of put buy :\n\nMorning se sirf ICICI Bank hi support kar Raha tha and facing resistance @862. And Icici give up kar deta hai to bnf bhi fir gaya.', 'Sl 120', '174 . Thoda thoda book karate chalo.', '151👍 finally blast', 'Last try enter again sl 60', 'Exit @75 . Buy above 90  sl 68 .', 'Bnf buy 40600 put @82 sl 60', 'Gap down opening . Exit', 'Carry.', '105👍 hold', 'Bnf buy 40800 call @85 sl 60 ( keep btst position sizing)', 'Bad exit 😞', '255 high. Exit near to cost', 'Buy above 235 sl 208', '40400 call watch', '75👍 hope you enjoyed', '60👍  today monthly expiry book as per your comfort', 'Move sl 35', '50👍 book Partial', 'Buy finnifty 18000 put @40 sl 30', '400👍', 'Bnf buy 40100 call @350 sl 300', 'IRCTC good short today', 'High volatility in first 30 min . Wait and watch', '290 sl now', 'Today 15👍', 'Now move sl 270 no loss now', '350👍 book partial', '89 point down bnf . Initial stoploss 240 . Book partial around 340 to 350', 'BTST 39900 PUT', 'Exit with 1 point loss🙏', 'Buy 410 put @12.2 sl 10.5', 'Hindalco watch short side', 'Buy nifty 17550 call above 21 sl 10', '436👍👍', 'Bnf buy 40200 next week call 300 sl 268', '434.1👍', 'Buy tatamotor @432.3 sl 429', '93👍 move sl 68', '72👍 move sl 51', 'Bnf 180+ down 👍', 'Move sl 47 so no loss now', '67👍.  Book partial', 'Now keep sl 40', 'Nifty plus bnf minus opening. No clear indication .\n\nPlus today is a monthly expiry.\n\nSafe traders exit BTST. Others wait for 1 min. keep  day low sl . \n\nIf you get 20 to 30 points in nifty book partial and in bnf 70 to 80 points .', 'Current week', 'STBT NIFTY and  BNF  \nYOU CAN BUY 17550 PUT', '235 sl', 'Ye bhi 200 Jane wala', '208👍 move sl 178', 'Sl hit', 'Bnf buy 39800 put @84 sl 74 ( less quantity)', '136 sl', '40269❤️. Told u in advance.', 'Move sl 116', '141. book another 10 to 15 % move sl 88 so no loss now', 'Agar Paisa Banaya to 👍 kar do .', '120👍 . 90 to 120. Risk only 12 point', '111 book partial', 'Buy @92 sl 78', '17800 put watch', 'Both 42000 and 41600 down by 80%. 1% easily achieved 🙏', 'Move sl 19', 'High 48. Target missed by 5 point.', '43👍', 'Buy fin nifty 18350 call @27 sl 15', '40508👍 Almost done', '330👍 move sl 278', '300👍 move sl 228', 'Move sl 210 . So no loss now', '280👍 book Partial', '260👍 keep sl 190', '83+ gap up. Safe player exit near to cost . Other wait for 1 min', 'Booked 42000 and moved to 41600 .', 'BTST BNF 40700 put', '40600👍', 'Move sl 97', '112. Move sl 84', 'Break Friday low . 40500 coming', '98. move sl 73 no loss now', '90👍 book partial', 'Buy nifty 17900 put @73 sl 60', '70 to 80% premium fall in call. Now 41500 spot level stoploss.👍', '33👍', '1154👍', 'Ignore not triggered', 'Bnf buy 41300 call above 284 sl 248', 'Buy techm @1144 sl 1132', '🙏🙏', 'Sold 42000 call . Option seller sell.', 'No BTST', 'Exit', 'Bnf buy 40900 @207 put sl 178', '78 sl so no loss', '101👍 book partial', '95👍 move  sl 75', 'Buy nifty 17900 put @83 sl 70', 'Move sl 420', '398 sl'], 'message_time_list': ['2023-03-02T14:03:44.000+00:00', '2023-03-02T13:50:29.000+00:00', '2023-03-02T13:45:36.000+00:00', '2023-03-02T13:35:49.000+00:00', '2023-03-02T13:34:14.000+00:00', '2023-03-02T13:04:17.000+00:00', '2023-03-02T12:50:40.000+00:00', '2023-03-02T12:39:42.000+00:00', '2023-03-02T09:10:13.000+00:00', '2023-03-01T15:28:11.000+00:00', '2023-03-01T14:43:27.000+00:00', '2023-03-01T14:40:29.000+00:00', '2023-03-01T10:11:18.000+00:00', '2023-03-01T09:54:16.000+00:00', '2023-03-01T09:31:52.000+00:00', '2023-03-01T09:13:49.000+00:00', '2023-02-28T14:43:39.000+00:00', '2023-02-28T14:35:16.000+00:00', '2023-02-28T14:33:49.000+00:00', '2023-02-28T14:33:30.000+00:00', '2023-02-28T14:31:47.000+00:00', '2023-02-27T11:50:38.000+00:00', '2023-02-27T11:47:12.000+00:00', '2023-02-27T10:35:59.000+00:00', '2023-02-27T09:41:00.000+00:00', '2023-02-27T09:22:19.000+00:00', '2023-02-27T09:19:28.000+00:00', '2023-02-27T09:18:12.000+00:00', '2023-02-27T09:17:37.000+00:00', '2023-02- ...
# {'channel_url': 'https://t.me/capital_wisdom_options', 'message_list': ['🌟*Sealmatic India SME IPO*🌟\n\nIssue Opens : FEB 17\nIssue Closes : FEB 21\n\nIssue Size 56.24CR\n\nPrice Band 225\n\nLot Size 600\n\nApplication Amount 1,35,000\n\nAllotment 24-02-2023\n\nListing 01-03-2023\n\nRegistrar : Kfin technology\n\n----------------------------------------------\n\n🌟*Macfos Ltd SME IPO*🌟\n\nIssue Opens : FEB 17\nIssue Closes : FEB 21\n\nIssue Size 23.74 CR\n\nPrice Band 102\n\nLot Size 1200\n\nApplication Amount 1,22,400\n\nAllotment 24-02-2023\n\nListing 01-03-2023\n\nRegistrar : Bigshare ser Ltd', '🌟*Shera Energy Ltd NSE SME IPO*🌟\n\nIssue Opens : FEB 07\nIssue Closes : FEB 09\n\nIssue Size 35.2 CR\n\nPrice Band 57\n\nLot Size 2000\n\nApplication Amount 1,14,000\n\nAllotment 14-02-2023\n\nListing 17-02-2023\n\nRegistrar : Bigshare ser Ltd'], 'message_time_list': ['2023-02-17T10:32:50.000+00:00', '2023-02-07T10:42:40.000+00:00'], '$id': '640077394c314122f8a3', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$createdAt': '2023-03-02T10:15:21.312+00:00', '$updatedAt': '2023-03-02T10:15:21.312+00:00', '$collectionId': '64003ebf13d3e4e89ed9', '$databaseId': '64003d8507c5fd8322bf'}
# {'channel_url': 'https://t.me/everydayprofits', 'message_list': ['Not moving safe plz close it 53', 'MPHASIS 2000 PE ABOVE 55', 'Good morning everyone ❤️', 'FOR TAKING OUR MEMBERSHIP CLICK THE LINK GIVEN BELOW 👇 AND JOIN OUR PREMIUM CHANNEL \n\nhttps://link.qoohoo.in/9523018987\n\nOR \nDIRECT MESSAGE ME 👇\n\n@Profitseveryday01\n\n🟢PREMIUM MEMBERS BENEFITS 🟢\n\n✅ All trades comes with proper target and stoploss \n✅live market update in each and every trades \n✅ trailing stoploss for catch big profit \n✅ small stoploss big target \n✅ extra sureshot trades \n✅ daily 3-5 sureshot trades \n✅all trades in advance level, you can easily buy at our given level \n✅only stock option trades for intraday \n✅ personally support \n\n❇️ Capital requirements 25k-35k', '26.70 🔥', 'Safe plz book profit 💪💪', '26.50 🔥', '26 🔥', '25.80 🔥', 'JINDALSTEL 560 CE ABOVE 25.50', 'Good morning everyone ❤️', 'Safe plz book profit 🔥', '158 🔥', '157 🔥', '155 🔥', '152 🔥', '150 🔥', '148🔥', '147 🔥', '146 🔥', 'INDIAMART 4800 CE ABOVE 145', 'Good morning everyone ❤️', 'FOR TAKING OUR MEMBERSHIP CLICK THE LINK GIVEN BELOW 👇 AND JOIN OUR PREMIUM CHANNEL \n\nhttps://link.qoohoo.in/9523018987\n\nOR \nDIRECT MESSAGE ME 👇\n\n@Profitseveryday01\n\n🟢PREMIUM MEMBERS BENEFITS 🟢\n\n✅ All trades comes with proper target and stoploss \n✅live market update in each and every trades \n✅ trailing stoploss for catch big profit \n✅ small stoploss big target \n✅ extra sureshot trades \n✅ daily 3-5 sureshot trades \n✅all trades in advance level, you can easily buy at our given level \n✅only stock option trades for intraday \n✅ personally support \n\n❇️ Capital requirements 25k-35k', 'COFORGE \n123 TO 163 🔥🔥\nALL TARGET DONE ✅ \nPROFIT PER LOT \n6000++ 🔥🔥\nPREMIUM CHANNEL TRADE 😎😎', 'PVR \n60.50 TO 73.95 🔥🔥\nALMOST ALL TARGET DONE ✅ \nPROFIT PER LOT \n5400++ 💪💪\nPREMIUM CHANNEL TRADE 😎😎', 'BAJAJ-AUTO\n80 TO 104 🔥🔥\nALL TARGET DONE ✅ \nPROFIT PER LOT \n6000++ 💪💪\nPREMIUM CHANNEL TRADE 😎😎', 'FOR TAKING OUR MEMBERSHIP CLICK THE LINK GIVEN BELOW 👇 AND JOIN OUR PREMIUM CHANNEL \n\nhttps://link.qoohoo.in/9523018987\n\nOR \nDIRECT MESSAGE ME 👇\n\n@Profitseveryday01\n\n🟢PREMIUM MEMBERS BENEFITS 🟢\n\n✅ All trades comes with proper target and stoploss \n✅live market update in each and every trades \n✅ trailing stoploss for catch big profit \n✅ small stoploss big target \n✅ extra sureshot trades \n✅ daily 3-5 sureshot trades \n✅all trades in advance level, you can easily buy at our given level \n✅only stock option trades for intraday \n✅ personally support \n\n❇️ Capital requirements 25k-35k', '5000++ RUNNING PROFIT PER LOT 💪💪', '', '73 💪💪', '72 💪💪', '71 🔥', '70.60 🔥', '70 🔥', '', '69🔥', '68 🔥', '67.70 🔥', '67🔥', '66🔥', '65 🔥', '64 🔥', '63.50 🔥', 'Safe can book profit', '62.95 🔥', '62 🔥', '61.50 🔥', '61 🔥', 'PVR 1540 PE ABOVE 60.50', 'Good morning everyone ❤️', 'Safe can book profit', '21.20 🔥', '20.80 🔥', '20.40 🔥', 'AARTIIND 540 CE ABOVE 20.30', 'Good morning everyone ❤️', 'Monthly expiry day ..\nHighly volatile market', '74.45 🔥', '74 🔥', '73.50 🔥', '73 🔥', '72 🔥🔥', 'ASTRAL 1800 PE ABOVE 71.50', 'Still not active', 'March expiry', 'DIXON 2600 PE ABOVE 145', 'Good morning everyone ❤️', 'Good morning everyone \nToday we are not available.\nWill available from tomorrow onwards', '2900++ PROFIT PER LOT 🔥🔥', '5.70 🔥', 'Safe plz book profit 💪💪', '5.55 🔥', '5.40 🔥', '5.20 🔥', '5 🔥', '4.80 🔥', 'ABFRL 240 PE ABOVE 4.60\nMARCH EXPIRY', 'Good morning everyone ❤️', 'FOR TAKING OUR MEMBERSHIP CLICK THE LINK GIVEN BELOW 👇 AND JOIN OUR PREMIUM CHANNEL \n\nhttps://link.qoohoo.in/9523018987\n\nOR \nDIRECT MESSAGE ME 👇\n\n@Profitseveryday01\n\n🟢PREMIUM MEMBERS BENEFITS 🟢\n\n✅ All trades comes with proper target and stoploss \n✅live market update in each and every trades \n✅ trailing stoploss for catch big profit \n✅ small stoploss big target \n✅ extra sureshot trades \n✅ daily 3-5 sureshot trades \n✅all trades in advance level, you can easily buy at our given level \n✅only stock option trades for intraday \n✅ p ...
# {'channel_url': 'https://t.me/shreetechanalysis', 'message_list': ["ANGEL BROKING\n\n\nOFFER OFFER OFFER\n\nOpen A Demat Account in Angel One Through our Link \n👇👇👇👇👇 \n\nhttps://tinyurl.com/y2e2chfq\n\n\n\n\n\n🔹 Get Premium Service Free Of Cost\n🔹 Daily 2-3 Intraday Calls\n🔹 Calls in BankNifty , Stock Options & Equity\n🔹 Banknifty Trading Levels \n\n                       +\n\n3 Penny Stocks For Long Term  Investment \n     \n\nNOTE- IT IS MANDATORY TO TRADE IN THE ACCOUNT OPENED THROUGH OUR LINK👍👍\n\nIF YOU ARE NOT TRADING IN THE ACCOUNT THEN WITHIN A MONTH YOU'LL BE REMOVED FROM THE CHANNEL👍👍\n\n\n\nAfter Account Opening Will Add You in Our Premium Channel", '355👍👍', '350👍👍', '345👍👍', '340👍👍', '335👍👍', '330👍👍', '325👍👍', '320👍👍', '315👍👍', '310👍👍', 'BANKNIFTY 40900 PE\n\n\nBUY ABOVE 305\n\nTARGET 340,380,450+\n\nSTOP LOSS TO PREMIUM', "ANGEL BROKING\n\n\nOFFER OFFER OFFER\n\nOpen A Demat Account in Angel One Through our Link \n👇👇👇👇👇 \n\nhttps://tinyurl.com/y2e2chfq\n\n\n\n\n\n🔹 Get Premium Service Free Of Cost\n🔹 Daily 2-3 Intraday Calls\n🔹 Calls in BankNifty , Stock Options & Equity\n🔹 Banknifty Trading Levels \n\n                       +\n\n3 Penny Stocks For Long Term  Investment \n     \n\nNOTE- IT IS MANDATORY TO TRADE IN THE ACCOUNT OPENED THROUGH OUR LINK👍👍\n\nIF YOU ARE NOT TRADING IN THE ACCOUNT THEN WITHIN A MONTH YOU'LL BE REMOVED FROM THE CHANNEL👍👍\n\n\n\nAfter Account Opening Will Add You in Our Premium Channel", 'OUR SHORT TERM EQUITY TRADES ARE GIVING GOOD RETURNS👍👍', '', '', "MEMBER'S LOOKING TO JOIN OUR INDEX OPTIONS SERVICES CAN MAKE PAYMENT HERE\n\nSPECIAL OFFERS AVAILABLE 👍👍", 'https://rpy.club/g/VVD81PmZNB', "ANGEL BROKING\n\n\nOFFER OFFER OFFER\n\nOpen A Demat Account in Angel One Through our Link \n👇👇👇👇👇 \n\nhttps://tinyurl.com/y2e2chfq\n\n\n\n\n\n🔹 Get Premium Service Free Of Cost\n🔹 Daily 2-3 Intraday Calls\n🔹 Calls in BankNifty , Stock Options & Equity\n🔹 Banknifty Trading Levels \n\n                       +\n\n3 Penny Stocks For Long Term  Investment \n     \n\nNOTE- IT IS MANDATORY TO TRADE IN THE ACCOUNT OPENED THROUGH OUR LINK👍👍\n\nIF YOU ARE NOT TRADING IN THE ACCOUNT THEN WITHIN A MONTH YOU'LL BE REMOVED FROM THE CHANNEL👍👍\n\n\n\nAfter Account Opening Will Add You in Our Premium Channel", '525👍👍', '520👍👍', '515👍👍', '510👍👍', '505👍👍', 'BANKNIFTY 40200 CE\n\nBUY ABOVE 500\n\nTARGET 540,580,620+\n\nSTOP LOSS TO PREMIUM', '', "ANGEL BROKING\n\n\nOFFER OFFER OFFER\n\nOpen A Demat Account in Angel One Through our Link \n👇👇👇👇👇 \n\nhttps://tinyurl.com/y2e2chfq\n\n\n\n\n\n🔹 Get Premium Service Free Of Cost\n🔹 Daily 2-3 Intraday Calls\n🔹 Calls in BankNifty , Stock Options & Equity\n🔹 Banknifty Trading Levels \n\n                       +\n\n3 Penny Stocks For Long Term  Investment \n     \n\nNOTE- IT IS MANDATORY TO TRADE IN THE ACCOUNT OPENED THROUGH OUR LINK👍👍\n\nIF YOU ARE NOT TRADING IN THE ACCOUNT THEN WITHIN A MONTH YOU'LL BE REMOVED FROM THE CHANNEL👍👍\n\n\n\nAfter Account Opening Will Add You in Our Premium Channel", 'LAST 1 SEAT FOR THE 6000 PER YEAR OFFER👍👍', 'SEAT 4 DONE\n\n\nLAST 1 SEAT FOR 6000 PER YEAR!!👍👍', 'SEAT 3 DONE\n\n\n\n\nTHE PRICE WILL BE 7000 FROM THE MONTH OF MARCH!', 'SEAT 2 DONE👍👍', 'SEAT 1 DONE!!\n\n\nTHE PRICE WILL BE 7000 FROM THE MONTH OF MARCH!', "WE ARE UP WITH BUMPER OFFER✅✅\n\n\nGET YEARLY MEMBERSHIP AT 6000👍👍\n\nSERVICES OFFERED:\n✓✓NIFTY AND BANKNIFTY OPTIONS👍👍\n✓✓ SHORT TERM EQUITY👍👍\n✓✓ LONG TERM EQUITY👍👍\n\n\nACCURACY 90%+👍👍\n\nDAILY 1-2 TRADES😊😊\n\n\nDAILY 1-2 TRADES IN THE MORNING SO THAT YOU'LL BE FREE BY 10👍👍\n\nOFFER IS LIMITED TO 5 SEATS ONLY STRICTLY\n\n\nQUERIES @SHRETECHANALYSIS", "TODAY'S PREMIUM CHANNEL TRADE\n\n\n40600 PE\n\n\n445 TO 550👍👍", '550👍👍\n\nALL TARGETS ACHIEVED!!👍👍', '540👍👍', '530👍👍', '520👍👍', '510👍👍', '500👍👍', '495👍👍', '490👍👍', '485👍👍', 'TARGET 1 TAKEN👍👍', '480👍👍', '470👍👍', '465👍👍', '460👍👍', '455👍👍', '450👍👍', '1-2 LOTS\n\nBANKNIFTY 40600 PE\n\n\nBUY ABOVE 445\n\nTARGET 480,520,550+\n\nSTOP LOSS TO PREMIUM', "ANGEL BROKING\n\n\nOFFER OFFER OFFER ...
# {'channel_url': 'https://t.me/INTRADAY_001', 'message_list': ['Swing call:- \n\nBuy MHRIL @ 277 \n\nStoploss 270 \n\nTarget 290 / 310 +', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Breakout stock :-\n\nBuy HG Infra @ 726\n\nStoploss 695\n\nTarget 765/820\n\nRisk 4% only', 'Swing call:-\n\n\nBuy SAIL @ 84 \n\nStoploss 81  \n\nTarget 90/ 95', 'Buy Tatacomm 1191 \n\ntarget 1400/1600\n\nView 3 month .......', '#kpittech \n\nBreakout + Retest Done💚\n\nCPM 840 \n\nStoploss 800 ( DCB )\n\nTarget 900/1000+', 'Positional call:-\n\nAHL @ 240 \n\nStoploss 230 \n\nTarget 260 / 280', 'SWING TRADERS \n\nBUY KANSAINER @412.60 \n\nTARGET 450 , 470 , 500\n\nSL 335', 'Buy Network18 at 61.50-62\n\nTarget 65.50,67.50\n\nSL 59\n\nHolding 2 days', 'Buy Schafeffler buy 2950-2955 \n\nSL 2628 \n\ntarget 3500/3900\n\nView 15-20 days', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', '✅DLF\n\n✔Trendline Breakout\n✔Volume Build-up\n✔Respected Important Demand Zone\n✔Retest - 355\n✔Support - 345', 'Buy Prestige at 428-430\n\nTarget 450,460\n\nSL 398\n\nHolding 2-3 Days', '2470 - 2550 HIT 🎯🎯\n\n1ST TARGET ACHIEVED 🔥🔥\n\nBOOK PROFIT OR TRAIL SL', '2505 Now 🔥🔥', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'SWING TRADERS \n\nBUY POONAWALLA @ 314\n\nTARGET 360  400 , 500 \n\nSL - 300 \n\n45 DAYS TIME FRAME', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Buy HAL at 2470-2475\n\nTarget 2540,2570\n\nSL 2425\n\nHolding 2 Working Days', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Swing call :- \n\nBUY AMARA RAJA Battery @ 614 \n\nStoploss 590 \n\nTarget 650 / 700', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Upper Circuit ❤️❤️', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Risky Call\n\nBuy Adani Power @ 173 \n\nLC may open soon \n\nBig Block Deal', 'Positional call:- \n\nBuy NCC @94 \n\nStoploss 88 \n\nTarget :- 100, 108', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', 'Buy Sona Coms at 460-465\n\nTarget 495,520\n\nSL 430\n\nHolding 3 Working Days', 'Good Morning Traders 👏 \nHave A Great Day Ahead ✅', '#Adani Group  \n\nNet Debt / EBIDTA Ratio \n\n2013  7.6x\n\n2016  4.0x\n\n2022  3.2x \n\nGrowth of #AdaniGroup 🚀🚀🚀'], 'message_time_list': ['2023-03-02T11:02:59.000+00:00', '2023-03-02T08:19:33.000+00:00', '2023-03-01T14:21:59.000+00:00', '2023-03-01T09:45:42.000+00:00', '2023-02-28T10:55:30.000+00:00', '2023-02-28T09:52:31.000+00:00', '2023-02-28T09:25:08.000+00:00', '2023-02-20T09:23:49.000+00:00', '2023-02-17T11:06:19.000+00:00', '2023-02-17T10:13:56.000+00:00', '2023-02-17T08:25:20.000+00:00', '2023-02-17T00:21:11.000+00:00', '2023-02-16T12:15:06.000+00:00', '2023-02-16T11:47:25.000+00:00', '2023-02-16T09:36:56.000+00:00', '2023-02-16T08:15:00.000+00:00', '2023-02-15T09:58:45.000+00:00', '2023-02-15T08:43:19.000+00:00', '2023-02-14T10:29:09.000+00:00', '2023-02-14T08:26:36.000+00:00', '2023-02-13T09:26:59.000+00:00', '2023-02-13T08:12:03.000+00:00', '2023-02-10T08:14:20.000+00:00', '2023-02-09T08:20:19.000+00:00', '2023-02-08T11:32:43.000+00:00', '2023-02-08T08:23:45.000+00:00', '2023-02-07T10:29:03.000+00:00', '2023-02-07T09:48:17.000+00:00', '2023-02-07T08:29:31.000+00:00', '2023-02-06T11:10:17.000+00:00', '2023-02-06T08:37:15.000+00:00', '2023-02-05T19:37:34.000+00:00'], '$id': '640077395e00b6de2d7b', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$createdAt': '2023-03-02T10:15:21.385+00:00', '$updatedAt': '2023-03-02T10:15:21.385+00:00', '$collectionId': '64003ebf13d3e4e89ed9', '$databaseId': '64003d8507c5fd8322bf'}
# {'channel_url': 'https://t.me/Calls', 'message_list': ['', '', '', '', '', 'Buy Call\n\n🔥RAJESH EXPORTS🔥\n\n@628\n\nTarget :-🎯651\n\nStop Loss :-620\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥AXIS BANK 🔥\n\n@848\n\nTarget :-🎯867\n\nStop Loss :-833\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥HINDALCO🔥\n\n@399\n\nTarget :-🎯415\n\nStop Loss :-390\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥AARTIIND🔥\n\n@534\n\nTarget :-🎯549\n\nStop Loss :-523\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥AUBANK🔥\n\n@599\n\nTarget :-🎯615\n\nStop Loss :-590\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥APOLLOTYRE🔥\n\n@319\n\nTarget :-🎯331\n\nStop Loss :-313\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥IBULHSGFIN🔥\n\n@100\n\nTarget :-🎯106\n\nStop Loss :-96\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥GLOBALVECT🔥\n\n@55\n\nTarget :-🎯60\n\nStop Loss :-51\n\nCall For Education Purpose Only', 'SL 637', 'Buy Call\n\n🔥ERIS🔥\n\n@647\n\nTarget :-🎯668\n\nStop Loss :-\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥KANSAINER🔥\n\n@413\n\nTarget :-🎯424\n\nStop Loss :-407\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥HSCL🔥\n\n@85\n\nTarget :-🎯90\n\nStop Loss :-82\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥BHARTI AIRTEL🔥\n\n@775\n\nTarget :-🎯796\n\nStop Loss :-763\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥SBIN🔥\n\n@519\n\nTarget :-🎯538\n\nStop Loss :-510\n\nCall For Education Purpose Only', '', '', 'Buy Call\n\n🔥POWER GRID🔥\n\n@213\n\nTarget :-🎯222\n\nStop Loss :-206\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥WIPRO🔥\n\n@397\n\nTarget :-🎯411\n\nStop Loss :-388\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥ADANIPORTS🔥\n\n@586\n\nTarget :-🎯600\n\nStop Loss :-579\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥NTPC🔥\n\n@173\n\nTarget :-🎯177\n\nStop Loss :-170\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥PRESTIGE🔥\n\n@433\n\nTarget :-🎯448\n\nStop Loss :-427\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥NH🔥\n\n@726\n\nTarget :-🎯744\n\nStop Loss :-710\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥GLENMARK🔥\n\n@ 440\n\nTarget :- 451 🎯\n\nStop Loss :- 435\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥 ERIS 🔥\n\n@  643\n\nTarget :-  656 🎯\n\nStop Loss :- 637\n\nCall For Education Purpose Only', 'Good morning🌞', 'Buy Call\n\n🔥AVADHSUGER🔥\n\n@  451\n\nTarget :- 462🎯\n\nStop Loss :- 446\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥APTUS🔥\n\n@  276\n\nTarget :- 282 🎯\n\nStop Loss :- 270\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥GLENMARK🔥\n\n@ 421\n\nTarget :-🎯432\n\nStop Loss :-410\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥BFUTILITIE🔥\n\n@378\n\nTarget :-🎯389\n\nStop Loss :-369\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥BSL🔥\n\n@ 190\n\nTarget :-🎯196\n\nStop Loss :-187\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥GEEKAYWIRE🔥\n\n@ 132\n\nTarget :-🎯138\n\nStop Loss :-128\n\nCall For Education Purpose Only', '', '', '', '', '', 'Buy Call\n\n🔥UPL🔥\n\n@ 732\n\nTarget :- 749🎯\n\nStop Loss :-725\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥PETRONET🔥\n\n@ 223\n\nTarget :- 228🎯\n\nStop Loss : 219\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥 BANDHAN BK🔥\n\n@ 242\n\nTarget :- 249🎯\n\nStop Loss :-238\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥AMARAJABAT🔥\n\n@ 606\n\nTarget :- 620 🎯\n\nStop Loss :-598\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥AGARIND🔥\n\n@ 685\n\nTarget :-700🎯\n\nStop Loss :-677\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥HINDALCO🔥\n\n@438\n\nTarget :-🎯451\n\nStop Loss :-429\n\nCall For Education Purpose Only', 'Good morning', 'Buy Call\n\n🔥AARTIND🔥\n\n@546\n\nTarget :-🎯566\n\nStop Loss :-533\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥HDFCLIFE🔥\n\n@504\n\nTarget :-🎯518\n\nStop Loss :-497\n\nCall For Education Purpose Only', 'Buy Call\n\n🔥AXISBANK🔥\n\n@ 889\n\nTarget :- 913🎯\n\nStop Loss  ...
# {'channel_url': 'https://t.me/shreeganeshstocksandinvestments', 'message_list': ['BUY TEJASNET\n\n\nCMP 602\n\nTARGET 650,670+\n\nSTOP LOSS AT 570', "MEMBER'S WHO HAS SUCCESSFULLY OPENED ACCOUNT WITH US CAN MESSAGE US\n\n\n@SHREEGANESHSTOCKS", 'WE ARE OFFICIAL SUB BROKERS WITH IIFL SECURITIES\n\n\nYOU CAN OPEN AND ACCOUNT WITH US FOLLOWING BELOW LINK\n👇👇👇👇👇👇👇👇👇👇👇👇👇\n\n\nhttps://cutt.ly/CLIcGF9\n\n0 ACCOUNT OPENING CHARGES/ AMC CHARGES FOR 1 YEAR👍\n\n0.05% FOR DELIVERY, INTRADAY,F&O CURRENCY AND COMMODITY TRADES👍\n\n\nIIFL IS ONE THE BEST FULL TIME BROKER BASED IN INDIA\n\n✅✅ IIFL PROVIDES ALL TYPES OF SERVICES INTO EQUITY, COMMODITY AND CURRENCY WITH THE ACCURACY OF ABOVE 85%\n\n✅✅ BENEFITS OF OPENING ACCOUNT WITH IIFL SECURITIES\n\n✓✓ DAILY TRADING AND INVESTMENT IDEAS\n\n✓✓ DAILY TRADING IDEAS IN COMMODITY AND CURRENCY\n\n✓✓ LIVE MARKET SUPPORT\n\n✓✓ 85%+ ACCURACY\n\n✅✅YOU CAN OPEN AN ACCOUNT WITH IIFL SECURITIES AND CHOOSE THE SERVICES YOU WANT TO TRADE OR INVEST IN\n\nWE WILL ADD YOU TO THE SEPERATE CHANNEL DEDICATED TO THE SEGMENT\n\n\n1⃣EQUITY\n2⃣FUTURES\n3⃣STOCK AND INDEX OPTIONS\n4⃣COMMODITY\n5⃣CURRENCY\n\nYOU CAN CHOOSE ANY OF THEM ACCORDING TO YOUR NEEDS AND EXPERIENCE!\n\n\nFOR ANY QUERIES YOU CAN CONTACT @SHREEGANESHSTOCKS\n\nTHANK YOU👍👍', 'BUY GSPL\n\nCMP 273\n\nTARGET 280,290,300+\n\nSTOP LOSS 260', 'SHORT TERM EQUITY\n\nBUY JUSTDIAL\n\nCMP 640\n\nTARGET 660,680,700+\n\nSTOP LOSS 610'], 'message_time_list': ['2023-02-20T14:53:12.000+00:00', '2023-02-16T21:36:19.000+00:00', '2023-02-15T12:47:04.000+00:00', '2023-02-14T12:57:47.000+00:00', '2023-02-13T09:43:43.000+00:00'], '$id': '640077396a0ab16e1317', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$createdAt': '2023-03-02T10:15:21.434+00:00', '$updatedAt': '2023-03-02T10:15:21.434+00:00', '$collectionId': '64003ebf13d3e4e89ed9', '$databaseId': '64003d8507c5fd8322bf'}
# {'channel_url': 'https://t.me/RatnakarSecuritiesPvtLtd', 'message_list': ['BTST : PANAMAPET CMP 320.70', 'NIFTY FUTURES : SUSTAINING ABOVE 17456 AND 17465 CAN GIVE A DECENT  UPMOVE', '', 'BTST : GPPL CMP 109.70', 'BTST : WEBELSOLAR CMP 81.20', 'INDUSINDBK GIVEN AT 1085 TOUCHED 1099', 'INTRADAY : BUY INDUSINDBK CMP 1085 SL 1072 TARGET 1100+', 'INTRADAY : BUY GREENPANEL ABOVE 296 SL 291 TARGET 306+', 'INTRADAY : BUY BDL ABOVE 981 SL 970 TARGET 1000+', 'INTRADAY : BUY GPPL ABOVE 109.50 - 110 SL 107 TARGET 120+', 'INTRADAY : BUY CCL ABOVE 558 SL 550 TARGET 570 - 575 - 580+', 'BTST UPDATE\n\nABCAPITAL GIVEN AT 145.75 GOING STRONG AT 149.70', '', 'BTST : ABCAPITAL CMP 145.75', 'INTRADAY : BUY ABCAPITAL CMP 146.60 SL 144.60 TARGET 155+', 'PFOCUS GIVEN YESTERDAY AT 76 TOUCHED 80.65', '', 'BTST : PFOCUS CMP 76', '', 'BTST : NIFTY FUTURES CMP 17561', 'BTST : GSPL CMP 280', 'BTST : RADICO CMP 1174', 'NIFTY FUTURES : SUTAINING ABOVE 17562 CAN GIVE A NICE UPMOVE SL 17500 TARGET 17640 - 17670', 'HBSL DID 49.15 TO 51.85', 'INTRADAY : BUY HBSL CMP 49.15 SL 47 TARGET 55+', '', 'INTRADAY UPDATE\n\nINDUSTOWER GIVEN A BUY AT 171 GOING STRONG AT 175+', 'BTST : M&MFIN CMP 256.50', 'INTRADAY :BUY INDUSTOWER CMP 171 SL 168 TARGET 180+', 'INTRADAY : BUY SYRMA ABOVE 281 SL 277 TARGET 290+', 'INTRADAY : BUY ICIL ABOVE 135 SL 132 TARGET 145+', '', 'BTST : MINDACORP CMP 197', 'INTRADAY : BUY GPPL CMP 102.80 SL 100 TARGET 113+', 'INTRADAY : BUY AURIONPRO CMP 380.50 SL 375 TARGET 390+', 'Morning Messages..\n\nSemiconductor manufacturing to start very soon in India: IT secretary\nElectronics and IT secretary Alkesh Kumar Sharma on Tuesday said that the production of semiconductors in the country will start very soon. He was responding to a query around plan of action of the Ministry of Electronics and IT after state-owned company Energy Efficiency Services Limited (EESL) raised the issue of shortage of electronic chip and printed circuit board (PCB or motherboard) hindering domestic production of electric meters. "India will be one of those top 6-7 partners which will have semiconductor manufacturing. It will happen very soon," Sharma said. Speaking at a conference on technology transfer by C-DAC, Thiruvananthapuram for local manufacturing of smart meters and electric chargers, Sharma said Meity has taken lead in technology development, be it electronic or automotive sector, artificial intelligence.\n\n\'Cheaper, faster, safer\': India, Singapore launch real-time payments link\nIn the first such collaboration for India, the country’s flagship payments platform, the Unified Payments Interface (UPI), and Singapore’s PayNow payment system have launched a real-time cross-border payment linkage system. The linkage, which was launched by Prime Minister (PM) Narendra Modi and Singapore’s PM Lee Hsien Loong on Tuesday, was kicked off by a live cross-border transaction between Reserve Bank of India Governor Shaktikanta Das and Monetary Authority of Singapore Managing Director Ravi Menon, using mobile phones. The linkage will enable users to transfer funds held in bank accounts or e-wallets to and from India using only the UPI ID, mobile number, or Virtual Payment Address (VPA), the RBI said.\n\nInvestments worth Rs 1.5 trn likely on data centres in next six years: Icra\nCredit rating agency Icra on Tuesday said Indian and foreign corporations may invest over Rs 1.5 trillion in the next six years on expanding their data centre capacities in India, marking a six-fold growth. A data centre is a large group of networked computer servers used by organisations for the remote storage, processing, or distribution of huge amounts of data. India\'s total data centre capacity is currently pegged at 870 Mw, powered by 138 units. Icra said the country could add 4,900-5,000 Mw of in the next six years. Mumbai, Hyderabad and NCR will account for 70-75 per cent of the installed capacity in coming years. Providing infrastructure status to data centres, special incentives from Central ...

# %%
def list_doc():
    p("Running List Document API")
    response = databases.list_documents(
        database_id,
        collection_id
    )
    print(response)
    
list_doc()
# Out:
# Running List Document API
# {'total': 1, 'documents': [{'name': 'Spider Man', 'release_year': 1920, 'rating': 98.5, 'kids': False, 'email': None, '$id': '63ff59a6cd9f3343eebe', '$createdAt': '2023-03-01T13:56:54.842+00:00', '$updatedAt': '2023-03-01T13:56:54.842+00:00', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$collectionId': '63ff594cd836f0e980b6', '$databaseId': '63ff5933737f37fc287b'}]}

# %%
def delete_doc():
    p("Running Delete Database API")
    response = databases.delete_document(
        database_id,
        collection_id,
        document_id
    )
    print(response)

delete_doc()
# Out:
# Running Delete Database API
# b''

# %%
def delete_collection():
    p("Running Delete Collection API")
    response = databases.delete_collection(
        database_id,
        collection_id
    )
    print(response)

delete_collection()

# %%
def delete_database():
    p("Running Delete Database API")
    response = databases.delete(database_id)
    print(response)

delete_database()

# %%
def create_bucket():
    global bucket_id

    p("Running Create Bucket API")
    response = storage.create_bucket(
        bucket_id=ID.unique(),
        name='awesome bucket',
        file_security=True,
        permissions=[
            Permission.read(Role.any()),
            Permission.create(Role.users()),
            Permission.update(Role.users()),
            Permission.delete(Role.users()),
        ]
    )
    bucket_id = response['$id']
    print(response)

create_bucket()

# %%
def list_buckets():
    p("Running List Buckets API")
    response = storage.list_buckets()
    print(response)

list_buckets()

# %%
def upload_file():
    global file_id

    p("Running Upload File API")
    response = storage.create_file(
        bucket_id,
        file_id=ID.unique(),
        file=InputFile.from_path("./resources/nature.jpg"),
    )
    file_id = response['$id']
    print(response)
    
upload_file()

# %%
def list_files():
    p("Running List Files API")
    response = storage.list_files(bucket_id)
    print(response)
    
list_files()

# %%
def delete_file():
    p("Running Delete File API")
    response = storage.delete_file(bucket_id, file_id)
    print(response)
    
delete_file()

# %%
def delete_bucket():
    p("Running Delete Bucket API")
    response = storage.delete_bucket(bucket_id)
    print(response)
    
delete_bucket()

# %%
def create_user():
    global user_id

    name = str(randrange(1, maxsize))
    p("Running Create User API")
    response = users.create(
        user_id=ID.unique(),
        email=f'{name}@test.com',
        password=f'{name}@123',
        name=name
    )
    user_id = response['$id']
    print(response)
    
create_user()

# %%
def list_user():
    p("Running List User API")
    response = users.list()
    print(response)
    
list_user()

# %%
def delete_user():
    p("Running Delete User API")
    response = users.delete(user_id)
    print(response)
    
delete_user()

# %%
def create_function():
    global function_id

    p("Running Create Function API")
    response = functions.create(
        function_id=ID.unique(),
        name='Test Function',
        execute=[Role.any()],
        runtime='python-3.9',
    )
    function_id = response['$id']
    print(response)
    
create_function()

# %%
def list_function():
    p("Running List Function API")
    response = functions.list()
    print(response)
    
list_function()

# %%
def delete_function():
    p("Running Delete Function API")
    response = functions.delete(function_id)
    print(response)
    
delete_function()

# %% [markdown]
# # Test All Functionalities

# %%
def run_all_tasks():

    # Databases
    create_database()
    create_collection()
    list_collections()
    add_doc()
    list_doc()
    delete_doc()
    delete_collection()
    delete_database()

    # Storage
    create_bucket()
    list_buckets()
    upload_file()
    list_files()
    delete_file()
    delete_bucket()

    # Users
    # get_account() # Use this only with JWT
    create_user()
    list_user()
    delete_user()

    # Functions
    create_function()
    list_function()
    delete_function()

if __name__ == "__main__":
    run_all_tasks()
    p("Successfully ran playground!")
# Out:
# Running Create Database API
# {'$id': '63ff3df39edaa0b3d980', 'name': 'Movies', '$createdAt': '2023-03-01T11:58:43.650+00:00', '$updatedAt': '2023-03-01T11:58:43.650+00:00'}
# Running Create Collection API
# {'$id': '63ff3df3af7928bc6e9c', '$createdAt': '2023-03-01T11:58:43.720+00:00', '$updatedAt': '2023-03-01T11:58:43.720+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'databaseId': '63ff3df39edaa0b3d980', 'name': 'Movies', 'enabled': True, 'documentSecurity': True, 'attributes': [], 'indexes': []}
# {'key': 'name', 'type': 'string', 'status': 'processing', 'required': True, 'array': False, 'size': 255, 'default': None}
# {'key': 'release_year', 'type': 'integer', 'status': 'processing', 'required': True, 'array': False, 'min': 0, 'max': 9999, 'default': None}
# {'key': 'rating', 'type': 'double', 'status': 'processing', 'required': True, 'array': False, 'min': 0, 'max': 99.99, 'default': None}
# {'key': 'kids', 'type': 'boolean', 'status': 'processing', 'required': True, 'array': False, 'default': None}
# {'key': 'email', 'type': 'string', 'status': 'processing', 'required': False, 'array': False, 'format': 'email', 'default': None}
# {'key': 'name_email_idx', 'type': 'fulltext', 'status': 'processing', 'attributes': ['name', 'email'], 'orders': []}
# Running List Collection API
# {'total': 1, 'collections': [{'$id': '63ff3df3af7928bc6e9c', '$createdAt': '2023-03-01T11:58:43.720+00:00', '$updatedAt': '2023-03-01T11:58:43.720+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'databaseId': '63ff3df39edaa0b3d980', 'name': 'Movies', 'enabled': True, 'documentSecurity': True, 'attributes': [{'key': 'name', 'type': 'string', 'status': 'available', 'required': True, 'array': False, 'size': 255, 'default': None}, {'key': 'release_year', 'type': 'integer', 'status': 'available', 'required': True, 'array': False, 'min': 0, 'max': 9999, 'default': None}, {'key': 'rating', 'type': 'double', 'status': 'available', 'required': True, 'array': False, 'min': 0, 'max': 99.99, 'default': None}, {'key': 'kids', 'type': 'boolean', 'status': 'available', 'required': True, 'array': False, 'default': None}, {'key': 'email', 'type': 'string', 'status': 'available', 'required': False, 'array': False, 'format': 'email', 'default': None}], 'indexes': [{'key': 'name_email_idx', 'type': 'fulltext', 'status': 'processing', 'attributes': ['name', 'email'], 'orders': []}]}]}
# Running Add Document API
# {'name': 'Spider Man', 'release_year': 1920, 'rating': 98.5, 'kids': False, '$id': '63ff3df5ddeb566e343d', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$createdAt': '2023-03-01T11:58:45.909+00:00', '$updatedAt': '2023-03-01T11:58:45.909+00:00', 'email': None, '$collectionId': '63ff3df3af7928bc6e9c', '$databaseId': '63ff3df39edaa0b3d980'}
# Running List Document API
# {'total': 1, 'documents': [{'name': 'Spider Man', 'release_year': 1920, 'rating': 98.5, 'kids': False, 'email': None, '$id': '63ff3df5ddeb566e343d', '$createdAt': '2023-03-01T11:58:45.909+00:00', '$updatedAt': '2023-03-01T11:58:45.909+00:00', '$permissions': ['read("users")', 'update("users")', 'delete("users")'], '$collectionId': '63ff3df3af7928bc6e9c', '$databaseId': '63ff3df39edaa0b3d980'}]}
# Running Delete Database API
# b''
# Running Delete Collection API
# b''
# Running Delete Database API
# b''
# Running Create Bucket API
# {'$id': '63ff3df6009b9549218d', '$createdAt': '2023-03-01T11:58:46.002+00:00', '$updatedAt': '2023-03-01T11:58:46.002+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'fileSecurity': True, 'name': 'awesome bucket', 'enabled': True, 'maximumFileSize': 30000000, 'allowedFileExtensions': [], 'compression': 'none', 'encryption': True, 'antivirus': True}
# Running List Buckets API
# {'total': 3, 'buckets': [{'$id': '63c42fc7c4a42fbec18b', '$createdAt': '2023-01-15T16:54:31.805+00:00', '$updatedAt': '2023-01-15T16:54:31.805+00:00', '$permissions': [], 'fileSecurity': False, 'name': 'newbkt', 'enabled': True, 'maximumFileSize': 30000000, 'allowedFileExtensions': [], 'compression': 'none', 'encryption': True, 'antivirus': True}, {'$id': '63ff3d45955fc481034a', '$createdAt': '2023-03-01T11:55:49.613+00:00', '$updatedAt': '2023-03-01T11:55:49.613+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'fileSecurity': True, 'name': 'awesome bucket', 'enabled': True, 'maximumFileSize': 30000000, 'allowedFileExtensions': [], 'compression': 'none', 'encryption': True, 'antivirus': True}, {'$id': '63ff3df6009b9549218d', '$createdAt': '2023-03-01T11:58:46.002+00:00', '$updatedAt': '2023-03-01T11:58:46.002+00:00', '$permissions': ['read("any")', 'create("users")', 'update("users")', 'delete("users")'], 'fileSecurity': True, 'name': 'awesome bucket', 'enabled': True, 'maximumFileSize': 30000000, 'allowedFileExtensions': [], 'compression': 'none', 'encryption': True, 'antivirus': True}]}
# Running Upload File API
# {'$id': '63ff3df61d59ba2a62c2', 'bucketId': '63ff3df6009b9549218d', '$createdAt': '2023-03-01T11:58:46.126+00:00', '$updatedAt': '2023-03-01T11:58:46.126+00:00', '$permissions': [], 'name': 'nature.jpg', 'signature': '3f0f3173e56f4b8ad0f41d12ffa43d7d', 'mimeType': 'image/jpeg', 'sizeOriginal': 71325, 'chunksTotal': 1, 'chunksUploaded': 1}
# Running List Files API
# {'total': 1, 'files': [{'$id': '63ff3df61d59ba2a62c2', 'bucketId': '63ff3df6009b9549218d', '$createdAt': '2023-03-01T11:58:46.126+00:00', '$updatedAt': '2023-03-01T11:58:46.126+00:00', '$permissions': [], 'name': 'nature.jpg', 'signature': '3f0f3173e56f4b8ad0f41d12ffa43d7d', 'mimeType': 'image/jpeg', 'sizeOriginal': 71325, 'chunksTotal': 1, 'chunksUploaded': 1}]}
# Running Delete File API
# b''
# Running Delete Bucket API
# b''
# Running Create User API
# {'$id': '63ff3df62e8add94a0c0', '$createdAt': '2023-03-01T11:58:46.384+00:00', '$updatedAt': '2023-03-01T11:58:46.384+00:00', 'name': '5975016752265055906', 'password': '$argon2id$v=19$m=65536,t=4,p=3$V0pQZE5ackN1cHBNTHIySw$V+7OeaIT48DLXKGugdthg9Wg66JqlLEVuuzcvIP/A9A', 'hash': 'argon2', 'hashOptions': {'type': 'argon2', 'memoryCost': 2048, 'timeCost': 4, 'threads': 3}, 'registration': '2023-03-01T11:58:46.384+00:00', 'status': True, 'passwordUpdate': '2023-03-01T11:58:46.384+00:00', 'email': '5975016752265055906@test.com', 'phone': '', 'emailVerification': False, 'phoneVerification': False, 'prefs': {}}
# Running List User API
# {'total': 3, 'users': [{'$id': 'dfgdfgdfgd123123g', '$createdAt': '2023-01-15T06:27:32.107+00:00', '$updatedAt': '2023-01-15T14:01:53.768+00:00', 'name': 'My Name', 'password': '$argon2id$v=19$m=65536,t=4,p=3$M1JJZlRlRkpEclhHcUpzdw$Ri/CuV5+27Cs3qrmm9AIOMDn9y8yDeBwS6oyOFL7DxU', 'hash': 'argon2', 'hashOptions': {'type': 'argon2', 'memoryCost': 2048, 'timeCost': 4, 'threads': 3}, 'registration': '2023-01-15T06:27:32.106+00:00', 'status': True, 'passwordUpdate': '2023-01-15T14:01:53.768+00:00', 'email': 'hemangjoshi37a@gmail.com', 'phone': '', 'emailVerification': True, 'phoneVerification': False, 'prefs': {}}, {'$id': '63c4125b35a4e4643917', '$createdAt': '2023-01-15T14:48:59.421+00:00', '$updatedAt': '2023-01-17T07:10:38.533+00:00', 'name': 'hjhj', 'password': '$argon2id$v=19$m=65536,t=4,p=3$VjM1RnVrVkIzVTEwLlhUQg$edOPHQgnF5NOWh2unoWWey7s7OJT1TEFYJLDY4FdGgA', 'hash': 'argon2', 'hashOptions': {'type': 'argon2', 'memoryCost': 2048, 'timeCost': 4, 'threads': 3}, 'registration': '2023-01-15T14:48:59.421+00:00', 'status': True, 'passwordUpdate': '2023-01-15T14:48:59.421+00:00', 'email': 'hemangjoshi37a2@gmail.com', 'phone': '', 'emailVerification': True, 'phoneVerification': False, 'prefs': {}}, {'$id': '63ff3df62e8add94a0c0', '$createdAt': '2023-03-01T11:58:46.384+00:00', '$updatedAt': '2023-03-01T11:58:46.384+00:00', 'name': '5975016752265055906', 'password': '$argon2id$v=19$m=65536,t=4,p=3$V0pQZE5ackN1cHBNTHIySw$V+7OeaIT48DLXKGugdthg9Wg66JqlLEVuuzcvIP/A9A', 'hash': 'argon2', 'hashOptions': {'type': 'argon2', 'memoryCost': 2048, 'timeCost': 4, 'threads': 3}, 'registration': '2023-03-01T11:58:46.384+00:00', 'status': True, 'passwordUpdate': '2023-03-01T11:58:46.384+00:00', 'email': '5975016752265055906@test.com', 'phone': '', 'emailVerification': False, 'phoneVerification': False, 'prefs': {}}]}
# Running Delete User API
# b''
# Running Create Function API
# {'$id': '63ff3df66c6742d9b776', '$createdAt': '2023-03-01T11:58:46.444+00:00', '$updatedAt': '2023-03-01T11:58:46.444+00:00', 'execute': ['any'], 'name': 'Test Function', 'enabled': True, 'runtime': 'python-3.9', 'deployment': '', 'vars': [], 'events': [], 'schedule': '', 'scheduleNext': '', 'schedulePrevious': '', 'timeout': 15}
# Running List Function API
# {'total': 2, 'functions': [{'$id': '63c42f820a942f32131f', '$createdAt': '2023-01-15T16:53:22.043+00:00', '$updatedAt': '2023-01-15T16:53:22.043+00:00', 'execute': ['any'], 'name': 'pytest', 'enabled': True, 'runtime': 'python-3.9', 'deployment': '', 'vars': [], 'events': ['users.*.sessions.*.create'], 'schedule': '', 'scheduleNext': '', 'schedulePrevious': '', 'timeout': 15}, {'$id': '63ff3df66c6742d9b776', '$createdAt': '2023-03-01T11:58:46.444+00:00', '$updatedAt': '2023-03-01T11:58:46.444+00:00', 'execute': ['any'], 'name': 'Test Function', 'enabled': True, 'runtime': 'python-3.9', 'deployment': '', 'vars': [], 'events': [], 'schedule': '', 'scheduleNext': '', 'schedulePrevious': '', 'timeout': 15}]}
# Running Delete Function API
# b''
# Successfully ran playground!
